# %%
import pandas as pd

# %%
df_inat = pd.read_csv('../data/gbif/occurrence.txt', delimiter='\t', quotechar='"')
# Out:
# /var/folders/ms/2ygwp03d4b5526gc0h51spqh0000gn/T/ipykernel_5100/3809163833.py:1: DtypeWarning: Columns (100,108,110,111,112,114,115,118,121,128,130,136,138,139,140,141,150,152,153,154,156,157,158,159,160,161,162,163,164,165,166,168,169,171,178,180,189,190,191,204,208,211,212,214,215,219,228,229,247,255,256) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_inat = pd.read_csv('../data/gbif/occurrence.txt', delimiter='\t', quotechar='"')

# %%
df_eBird = pd.read_csv('../data/eBird/ebd_US-CA_201901_201912_relApr-2023/ebd_US-CA_201901_201912_relApr-2023.txt', sep='\t')
# Out:
# /var/folders/ms/2ygwp03d4b5526gc0h51spqh0000gn/T/ipykernel_5100/142200405.py:1: DtypeWarning: Columns (9,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_eBird = pd.read_csv('../data/eBird/ebd_US-CA_201901_201912_relApr-2023/ebd_US-CA_201901_201912_relApr-2023.txt', sep='\t')

# %%
df_inat.shape
# Out:
# (3321454, 259)

# %%
df_eBird.shape
# Out:
# (8694926, 50)

# %% [markdown]
# ## EDA on Bird Names. Can scientific names be used as a common key?

# %%
df_inat.head(10).to_clipboard()

# %%
[x for x in df_inat.columns if ('name' in x.lower())]
# Out:
# ['datasetName',
#  'organismName',
#  'scientificNameID',
#  'acceptedNameUsageID',
#  'parentNameUsageID',
#  'originalNameUsageID',
#  'nameAccordingToID',
#  'namePublishedInID',
#  'scientificName',
#  'acceptedNameUsage',
#  'parentNameUsage',
#  'originalNameUsage',
#  'nameAccordingTo',
#  'namePublishedIn',
#  'namePublishedInYear',
#  'genericName',
#  'vernacularName',
#  'acceptedScientificName',
#  'verbatimScientificName',
#  'typifiedName',
#  'level0Name',
#  'level1Name',
#  'level2Name',
#  'level3Name']

# %%
name_columns_iNat = [
    'scientificName',
    'species',
    'acceptedScientificName',
    'verbatimScientificName'
]

# %%
for col in name_columns_iNat:
    print(f"Unique names in column: {col} is {df_inat[col].nunique()}")
# Out:
# Unique names in column: scientificName is 47112
# Unique names in column: species is 40090
# Unique names in column: acceptedScientificName is 46022
# Unique names in column: verbatimScientificName is 48130

# %%
df_eBird.head(10).to_clipboard()

# %%
name_columns_eBird = [
    'COMMON NAME',
    'SCIENTIFIC NAME',
]

# %%
for col in name_columns_eBird:
    print(f"Unique names in column: {col} is {df_eBird[col].nunique()}")
# Out:
# Unique names in column: COMMON NAME is 865
# Unique names in column: SCIENTIFIC NAME is 865

# %%
df_eBird.groupby(name_columns_eBird).count()
# Out:
#                                                                GLOBAL UNIQUE IDENTIFIER  \
# COMMON NAME                 SCIENTIFIC NAME
# Abert's Towhee              Melozone aberti                                        2011
# Acanthis/Spinus sp.         Acanthis/Spinus sp.                                      36
# Accipiter sp.               Accipiter sp.                                           835
# Acorn Woodpecker            Melanerpes formicivorus                               75840
# African Collared-Dove       Streptopelia roseogrisea                                 15
# ...                                                                                 ...
# white egret sp.             Ardea/Egretta/Bubulcus sp.                              175
# white-winged gull sp.       Larus sp. (white-winged gull sp.)                        36
# woodpecker sp.              Picidae sp.                                            1171
# wren sp.                    Troglodytidae sp.                                       803
# yellow-bellied kingbird sp. Tyrannus sp. (yellow-bellied)                           452
#
#                                                                LAST EDITED DATE  \
# COMMON NAME                 SCIENTIFIC NAME
# Abert's Towhee              Melozone aberti                                2011
# Acanthis/Spinus sp.         Acanthis/Spinus sp.                              36
# Accipiter sp.               Accipiter sp.                                   835
# Acorn Woodpecker            Melanerpes formicivorus                       75840
# African Collared-Dove       Streptopelia roseogrisea                         15
# ...                                                                         ...
# white egret sp.             Ardea/Egretta/Bubulcus sp.                      175
# white-winged gull sp.       Larus sp. (white-winged gull sp.)                36
# woodpecker sp.              Picidae sp.                                    1171
# wren sp.                    Troglodytidae sp.                               803
# yellow-bellied kingbird sp. Tyrannus sp. (yellow-bellied)                   452
#
#                                                                TAXONOMIC ORDER  \
# COMMON NAME                 SCIENTIFIC NAME
# Abert's Towhee              Melozone aberti                               2011
# Acanthis/Spinus sp.         Acanthis/Spinus sp.                             36
# Accipiter sp.               Accipiter sp.                                  835
# Acorn Woodpecker            Melanerpes formicivorus                      75840
# African Collared-Dove       Streptopelia roseogrisea                        15
# ...                                                                        ...
# white egret sp.             Ardea/Egretta/Bubulcus sp.                     175
# white-winged gull sp.       Larus sp. (white-winged gull sp.)               36
# woodpecker sp.              Picidae sp.                                   1171
# wren sp.                    Troglodytidae sp.                              803
# yellow-bellied kingbird sp. Tyrannus sp. (yellow-bellied)                  452
#
#                                                                CATEGORY  \
# COMMON NAME                 SCIENTIFIC NAME
# Abert's Towhee              Melozone aberti                        2011
# Acanthis/Spinus sp.         Acanthis/Spinus sp.                      36
# Accipiter sp.               Accipiter sp.                           835
# Acorn Woodpecker            Melanerpes formicivorus               75840
# African Collared-Dove       Streptopelia roseogrisea                 15
# ...                                                                 ...
# white egret sp.             Ardea/Egretta/Bubulcus sp.              175
# white-winged gull sp.       Larus sp. (white-winged gull sp.)        36
# woodpecker sp.              Picidae sp.                            1171
# wren sp.                    Troglodytidae sp.                       803
# yellow-bellied kingbird sp. Tyrannus sp. (yellow-bellied)           452
#
#                                                                TAXON CONCEPT ID  \
# COMMON NAME                 SCIENTIFIC NAME
# Abert's Towhee              Melozone aberti                                2011
# Acanthis/Spinus sp.         Acanthis/Spinus sp.                              36
# Accipiter sp.               Accipiter sp.                                   835
# Acorn Woodpecker            Melanerpes formicivorus                       75840
# African Collared-Dove       Streptopelia roseogrisea                         15
# ...                                                                         ...
# white egret sp.             Ardea/Egretta/Bubulcus sp.                      175
# white-winged gull sp.       Larus sp. (white-winged gull sp.)                36
# woodpecker sp.              Picidae sp.                                    1171
# wren sp.                    Troglodytidae sp.                               803
# yellow-bellied kingbird sp. Tyrannus sp. (yellow-bellied)                   452
#
#                                                                SUBSPECIES COMMON NAME  \
# COMMON NAME                 SCIENTIFIC NAME
# Abert's Towhee              Melozone aberti                                         0
# Acanthis/Spinus sp.         Acanthis/Spinus sp.                                     0
# Accipiter sp.               Accipiter sp.                                           0
# Acorn Woodpecker            Melanerpes formicivorus                               205
# African Collared-Dove       Streptopelia roseogrisea                               15
# ...                                                                               ...
# white egret sp.             Ardea/Egretta/Bubulcus sp.                              0
# white-winged gull sp.       Larus sp. (white-winged gull sp.)                       0
# woodpecker sp.              Picidae sp.                                             0
# wren sp.                    Troglodytidae sp.                                       0
# yellow-bellied kingbird sp. Tyrannus sp. (yellow-bellied)                           0
#
#                                                                SUBSPECIES SCIENTIFIC NAME  \
# COMMON NAME                 SCIENTIFIC NAME
# Abert's Towhee              Melozone aberti                                             0
# Acanthis/Spinus sp.         Acanthis/Spinus sp.                                         0
# Accipiter sp.               Accipiter sp.                                               0
# Acorn Woodpecker            Melanerpes formicivorus                                   205
# African Collared-Dove       Streptopelia roseogrisea                                   15
# ...                                                                                   ...
# white egret sp.             Ardea/Egretta/Bubulcus sp.                                  0
# white-winged gull sp.       Larus sp. (white-winged gull sp.)                           0
# woodpecker sp.              Picidae sp.                                                 0
# wren sp.                    Troglodytidae sp.                                           0
# yellow-bellied kingbird sp. Tyrannus sp. (yellow-bellied)                               0
#
#                                                                EXOTIC CODE  \
# COMMON NAME                 SCIENTIFIC NAME
# Abert's Towhee              Melozone aberti                              0
# Acanthis/Spinus sp.         Acanthis/Spinus sp.                          0
# Accipiter sp.               Accipiter sp.                                0
# Acorn Woodpecker            Melanerpes formicivorus                      0
# African Collared-Dove       Streptopelia roseogrisea                    15
# ...                                                                    ...
# white egret sp.             Ardea/Egretta/Bubulcus sp.                   0
# white-winged gull sp.       Larus sp. (white-winged gull sp.)            0
# woodpecker sp.              Picidae sp.                                  0
# wren sp.                    Troglodytidae sp.                            0
# yellow-bellied kingbird sp. Tyrannus sp. (yellow-bellied)                0
#
#                                                                OBSERVATION COUNT  \
# COMMON NAME                 SCIENTIFIC NAME
# Abert's Towhee              Melozone aberti                                 2011
# Acanthis/Spinus sp.         Acanthis/Spinus sp.                               36
# Accipiter sp.               Accipiter sp.                                    835
# Acorn Woodpecker            Melanerpes formicivorus                        75840
# African Collared-Dove       Streptopelia roseogrisea                          15
# ...                                                                          ...
# white egret sp.             Ardea/Egretta/Bubulcus sp.                       175
# white-winged gull sp.       Larus sp. (white-winged gull sp.)                 36
# woodpecker sp.              Picidae sp.                                     1171
# wren sp.                    Troglodytidae sp.                                803
# yellow-bellied kingbird sp. Tyrannus sp. (yellow-bellied)                    452
#
#                                                                BREEDING CODE  \
# COMMON NAME                 SCIENTIFIC NAME
# Abert's Towhee              Melozone aberti                               41
# Acanthis/Spinus sp.         Acanthis/Spinus sp.                            0
# Accipiter sp.               Accipiter sp.                                  1
# Acorn Woodpecker            Melanerpes formicivorus                      776
# African Collared-Dove       Streptopelia roseogrisea                       1
# ...                                                                      ...
# white egret sp.             Ardea/Egretta/Bubulcus sp.                    14
# white-winged gull sp.       Larus sp. (white-winged gull sp.)              0
# woodpecker sp.              Picidae sp.                                    3
# wren sp.                    Troglodytidae sp.                              0
# yellow-bellied kingbird sp. Tyrannus sp. (yellow-bellied)                  6
#
#                                                                ...  \
# COMMON NAME                 SCIENTIFIC NAME                    ...
# Abert's Towhee              Melozone aberti                    ...
# Acanthis/Spinus sp.         Acanthis/Spinus sp.                ...
# Accipiter sp.               Accipiter sp.                      ...
# Acorn Woodpecker            Melanerpes formicivorus            ...
# African Collared-Dove       Streptopelia roseogrisea           ...
# ...                                                            ...
# white egret sp.             Ardea/Egretta/Bubulcus sp.         ...
# white-winged gull sp.       Larus sp. (white-winged gull sp.)  ...
# woodpecker sp.              Picidae sp.                        ...
# wren sp.                    Troglodytidae sp.                  ...
# yellow-bellied kingbird sp. Tyrannus sp. (yellow-bellied)      ...
#
#                                                                NUMBER OBSERVERS  \
# COMMON NAME                 SCIENTIFIC NAME
# Abert's Towhee              Melozone aberti                                2008
# Acanthis/Spinus sp.         Acanthis/Spinus sp.                              34
# Accipiter sp.               Accipiter sp.                                   834
# Acorn Woodpecker            Melanerpes formicivorus                       75517
# African Collared-Dove       Streptopelia roseogrisea                         15
# ...                                                                         ...
# white egret sp.             Ardea/Egretta/Bubulcus sp.                      174
# white-winged gull sp.       Larus sp. (white-winged gull sp.)                36
# woodpecker sp.              Picidae sp.                                    1162
# wren sp.                    Troglodytidae sp.                               801
# yellow-bellied kingbird sp. Tyrannus sp. (yellow-bellied)                   450
#
#                                                                ALL SPECIES REPORTED  \
# COMMON NAME                 SCIENTIFIC NAME
# Abert's Towhee              Melozone aberti                                    2011
# Acanthis/Spinus sp.         Acanthis/Spinus sp.                                  36
# Accipiter sp.               Accipiter sp.                                       835
# Acorn Woodpecker            Melanerpes formicivorus                           75840
# African Collared-Dove       Streptopelia roseogrisea                             15
# ...                                                                             ...
# white egret sp.             Ardea/Egretta/Bubulcus sp.                          175
# white-winged gull sp.       Larus sp. (white-winged gull sp.)                    36
# woodpecker sp.              Picidae sp.                                        1171
# wren sp.                    Troglodytidae sp.                                   803
# yellow-bellied kingbird sp. Tyrannus sp. (yellow-bellied)                       452
#
#                                                                GROUP IDENTIFIER  \
# COMMON NAME                 SCIENTIFIC NAME
# Abert's Towhee              Melozone aberti                                 924
# Acanthis/Spinus sp.         Acanthis/Spinus sp.                               2
# Accipiter sp.               Accipiter sp.                                   391
# Acorn Woodpecker            Melanerpes formicivorus                       23095
# African Collared-Dove       Streptopelia roseogrisea                          6
# ...                                                                         ...
# white egret sp.             Ardea/Egretta/Bubulcus sp.                       61
# white-winged gull sp.       Larus sp. (white-winged gull sp.)                17
# woodpecker sp.              Picidae sp.                                     246
# wren sp.                    Troglodytidae sp.                               332
# yellow-bellied kingbird sp. Tyrannus sp. (yellow-bellied)                   138
#
#                                                                HAS MEDIA  \
# COMMON NAME                 SCIENTIFIC NAME
# Abert's Towhee              Melozone aberti                         2011
# Acanthis/Spinus sp.         Acanthis/Spinus sp.                       36
# Accipiter sp.               Accipiter sp.                            835
# Acorn Woodpecker            Melanerpes formicivorus                75840
# African Collared-Dove       Streptopelia roseogrisea                  15
# ...                                                                  ...
# white egret sp.             Ardea/Egretta/Bubulcus sp.               175
# white-winged gull sp.       Larus sp. (white-winged gull sp.)         36
# woodpecker sp.              Picidae sp.                             1171
# wren sp.                    Troglodytidae sp.                        803
# yellow-bellied kingbird sp. Tyrannus sp. (yellow-bellied)            452
#
#                                                                APPROVED  \
# COMMON NAME                 SCIENTIFIC NAME
# Abert's Towhee              Melozone aberti                        2011
# Acanthis/Spinus sp.         Acanthis/Spinus sp.                      36
# Accipiter sp.               Accipiter sp.                           835
# Acorn Woodpecker            Melanerpes formicivorus               75840
# African Collared-Dove       Streptopelia roseogrisea                 15
# ...                                                                 ...
# white egret sp.             Ardea/Egretta/Bubulcus sp.              175
# white-winged gull sp.       Larus sp. (white-winged gull sp.)        36
# woodpecker sp.              Picidae sp.                            1171
# wren sp.                    Troglodytidae sp.                       803
# yellow-bellied kingbird sp. Tyrannus sp. (yellow-bellied)           452
#
#                                                                REVIEWED  \
# COMMON NAME                 SCIENTIFIC NAME
# Abert's Towhee              Melozone aberti                        2011
# Acanthis/Spinus sp.         Acanthis/Spinus sp.                      36
# Accipiter sp.               Accipiter sp.                           835
# Acorn Woodpecker            Melanerpes formicivorus               75840
# African Collared-Dove       Streptopelia roseogrisea                 15
# ...                                                                 ...
# white egret sp.             Ardea/Egretta/Bubulcus sp.              175
# white-winged gull sp.       Larus sp. (white-winged gull sp.)        36
# woodpecker sp.              Picidae sp.                            1171
# wren sp.                    Troglodytidae sp.                       803
# yellow-bellied kingbird sp. Tyrannus sp. (yellow-bellied)           452
#
#                                                                REASON  \
# COMMON NAME                 SCIENTIFIC NAME
# Abert's Towhee              Melozone aberti                         0
# Acanthis/Spinus sp.         Acanthis/Spinus sp.                     0
# Accipiter sp.               Accipiter sp.                           0
# Acorn Woodpecker            Melanerpes formicivorus                 0
# African Collared-Dove       Streptopelia roseogrisea                0
# ...                                                               ...
# white egret sp.             Ardea/Egretta/Bubulcus sp.              0
# white-winged gull sp.       Larus sp. (white-winged gull sp.)       0
# woodpecker sp.              Picidae sp.                             0
# wren sp.                    Troglodytidae sp.                       0
# yellow-bellied kingbird sp. Tyrannus sp. (yellow-bellied)           0
#
#                                                                TRIP COMMENTS  \
# COMMON NAME                 SCIENTIFIC NAME
# Abert's Towhee              Melozone aberti                              350
# Acanthis/Spinus sp.         Acanthis/Spinus sp.                            3
# Accipiter sp.               Accipiter sp.                                287
# Acorn Woodpecker            Melanerpes formicivorus                    20239
# African Collared-Dove       Streptopelia roseogrisea                       5
# ...                                                                      ...
# white egret sp.             Ardea/Egretta/Bubulcus sp.                    62
# white-winged gull sp.       Larus sp. (white-winged gull sp.)             18
# woodpecker sp.              Picidae sp.                                  278
# wren sp.                    Troglodytidae sp.                            263
# yellow-bellied kingbird sp. Tyrannus sp. (yellow-bellied)                142
#
#                                                                SPECIES COMMENTS  \
# COMMON NAME                 SCIENTIFIC NAME
# Abert's Towhee              Melozone aberti                                 137
# Acanthis/Spinus sp.         Acanthis/Spinus sp.                               1
# Accipiter sp.               Accipiter sp.                                   156
# Acorn Woodpecker            Melanerpes formicivorus                        2309
# African Collared-Dove       Streptopelia roseogrisea                         11
# ...                                                                         ...
# white egret sp.             Ardea/Egretta/Bubulcus sp.                       48
# white-winged gull sp.       Larus sp. (white-winged gull sp.)                20
# woodpecker sp.              Picidae sp.                                     325
# wren sp.                    Troglodytidae sp.                               116
# yellow-bellied kingbird sp. Tyrannus sp. (yellow-bellied)                    74
#
#                                                                Unnamed: 49
# COMMON NAME                 SCIENTIFIC NAME
# Abert's Towhee              Melozone aberti                              0
# Acanthis/Spinus sp.         Acanthis/Spinus sp.                          0
# Accipiter sp.               Accipiter sp.                                0
# Acorn Woodpecker            Melanerpes formicivorus                      0
# African Collared-Dove       Streptopelia roseogrisea                     0
# ...                                                                    ...
# white egret sp.             Ardea/Egretta/Bubulcus sp.                   0
# white-winged gull sp.       Larus sp. (white-winged gull sp.)            0
# woodpecker sp.              Picidae sp.                                  0
# wren sp.                    Troglodytidae sp.                            0
# yellow-bellied kingbird sp. Tyrannus sp. (yellow-bellied)                0
#
# [865 rows x 48 columns]

# %%
df_eBird['TAXON CONCEPT ID'].nunique()
# Out:
# 1088

# %%
df_eBird.groupby('SCIENTIFIC NAME')['TAXON CONCEPT ID'].nunique().sort_values(ascending=False)
# Out:
# SCIENTIFIC NAME
# Junco hyemalis                    9
# Melospiza melodia                 8
# Loxia curvirostra                 7
# Zonotrichia leucophrys            7
# Leiothlypis celata                6
#                                  ..
# Empidonax wrightii/oberholseri    1
# Estrilda melpoda                  1
# Estrilda troglodytes              1
# Euodice malabarica                1
# Zosterops sp.                     1
# Name: TAXON CONCEPT ID, Length: 865, dtype: int64

# %%
df_eBird[df_eBird['SCIENTIFIC NAME'] == "Junco hyemalis"]
# Out:
#                                GLOBAL UNIQUE IDENTIFIER  \
# 13559    URN:CornellLabOfOrnithology:EBIRD:OBS693135005
# 13560    URN:CornellLabOfOrnithology:EBIRD:OBS702682936
# 13561    URN:CornellLabOfOrnithology:EBIRD:OBS699877239
# 13562    URN:CornellLabOfOrnithology:EBIRD:OBS695455899
# 13563    URN:CornellLabOfOrnithology:EBIRD:OBS700292385
# ...                                                 ...
# 8693180  URN:CornellLabOfOrnithology:EBIRD:OBS840057789
# 8693181  URN:CornellLabOfOrnithology:EBIRD:OBS852424961
# 8693182  URN:CornellLabOfOrnithology:EBIRD:OBS842649454
# 8693183  URN:CornellLabOfOrnithology:EBIRD:OBS852425498
# 8693184  URN:CornellLabOfOrnithology:EBIRD:OBS838501378
#
#                    LAST EDITED DATE  TAXONOMIC ORDER CATEGORY  \
# 13559           2019-01-15 15:42:12            32449  species
# 13560    2021-11-08 10:25:50.618592            32449  species
# 13561           2019-01-18 16:58:44            32449  species
# 13562           2019-01-07 14:48:19            32449  species
# 13563           2019-01-19 17:50:58            32449  species
# ...                             ...              ...      ...
# 8693180  2021-04-03 19:08:18.202972            32455     issf
# 8693181  2021-12-29 00:17:07.992279            32455     issf
# 8693182         2019-12-27 12:40:44            32455     issf
# 8693183  2021-12-29 00:17:07.992279            32455     issf
# 8693184         2019-12-15 14:48:00            32455     issf
#
#          TAXON CONCEPT ID      COMMON NAME SCIENTIFIC NAME  \
# 13559    avibase-05FF3C9B  Dark-eyed Junco  Junco hyemalis
# 13560    avibase-05FF3C9B  Dark-eyed Junco  Junco hyemalis
# 13561    avibase-05FF3C9B  Dark-eyed Junco  Junco hyemalis
# 13562    avibase-05FF3C9B  Dark-eyed Junco  Junco hyemalis
# 13563    avibase-05FF3C9B  Dark-eyed Junco  Junco hyemalis
# ...                   ...              ...             ...
# 8693180  avibase-B1019ACB  Dark-eyed Junco  Junco hyemalis
# 8693181  avibase-B1019ACB  Dark-eyed Junco  Junco hyemalis
# 8693182  avibase-B1019ACB  Dark-eyed Junco  Junco hyemalis
# 8693183  avibase-B1019ACB  Dark-eyed Junco  Junco hyemalis
# 8693184  avibase-B1019ACB  Dark-eyed Junco  Junco hyemalis
#
#            SUBSPECIES COMMON NAME       SUBSPECIES SCIENTIFIC NAME  \
# 13559                         NaN                              NaN
# 13560                         NaN                              NaN
# 13561                         NaN                              NaN
# 13562                         NaN                              NaN
# 13563                         NaN                              NaN
# ...                           ...                              ...
# 8693180  Dark-eyed Junco (Oregon)  Junco hyemalis [oreganus Group]
# 8693181  Dark-eyed Junco (Oregon)  Junco hyemalis [oreganus Group]
# 8693182  Dark-eyed Junco (Oregon)  Junco hyemalis [oreganus Group]
# 8693183  Dark-eyed Junco (Oregon)  Junco hyemalis [oreganus Group]
# 8693184  Dark-eyed Junco (Oregon)  Junco hyemalis [oreganus Group]
#
#         EXOTIC CODE  ... NUMBER OBSERVERS ALL SPECIES REPORTED  \
# 13559           NaN  ...              2.0                    1
# 13560           NaN  ...              1.0                    1
# 13561           NaN  ...              1.0                    1
# 13562           NaN  ...              1.0                    0
# 13563           NaN  ...              3.0                    1
# ...             ...  ...              ...                  ...
# 8693180         NaN  ...              6.0                    1
# 8693181         NaN  ...              4.0                    1
# 8693182         NaN  ...              1.0                    1
# 8693183         NaN  ...              2.0                    1
# 8693184         NaN  ...              NaN                    0
#
#         GROUP IDENTIFIER HAS MEDIA APPROVED REVIEWED REASON  \
# 13559           G3765102         0        1        0    NaN
# 13560                NaN         0        1        0    NaN
# 13561                NaN         0        1        0    NaN
# 13562                NaN         0        1        0    NaN
# 13563                NaN         0        1        0    NaN
# ...                  ...       ...      ...      ...    ...
# 8693180         G4766200         0        1        0    NaN
# 8693181         G4880261         0        1        0    NaN
# 8693182              NaN         0        1        0    NaN
# 8693183         G4880269         0        1        0    NaN
# 8693184              NaN         0        1        0    NaN
#
#                                              TRIP COMMENTS SPECIES COMMENTS  \
# 13559                                                  NaN              NaN
# 13560                                                  NaN              NaN
# 13561                                                  NaN              NaN
# 13562                                                  NaN              NaN
# 13563    warm. partly cloudy. From Dwight way, above tr...              NaN
# ...                                                    ...              ...
# 8693180                                                NaN              NaN
# 8693181                                                NaN              NaN
# 8693182                                                NaN              NaN
# 8693183                                                NaN              NaN
# 8693184                                                NaN              NaN
#
#         Unnamed: 49
# 13559           NaN
# 13560           NaN
# 13561           NaN
# 13562           NaN
# 13563           NaN
# ...             ...
# 8693180         NaN
# 8693181         NaN
# 8693182         NaN
# 8693183         NaN
# 8693184         NaN
#
# [103806 rows x 50 columns]

# %%
(df_eBird.groupby('SCIENTIFIC NAME')['TAXON CONCEPT ID'].nunique() > 1).sum()
# Out:
# 140

# %% [markdown]
# Observations on eBird:
# - Only two name columns, 1-1 mapping between them, clearly to use Scientific Name
# - There are more Taxon ID than Scientific Name!
# - Some Scientific Name have more than one Taxon ID, 140 of those!
# - Not the other way around at least!

# %%
df_inat
# Out:
#              gbifID  abstract  accessRights  accrualMethod  \
# 0        1993720406       NaN           NaN            NaN
# 1        2006062344       NaN           NaN            NaN
# 2        3031816435       NaN           NaN            NaN
# 3        2235488964       NaN           NaN            NaN
# 4        2236210250       NaN           NaN            NaN
# ...             ...       ...           ...            ...
# 3321449  2529313761       NaN           NaN            NaN
# 3321450  2540812251       NaN           NaN            NaN
# 3321451  2574273979       NaN           NaN            NaN
# 3321452  3044719228       NaN           NaN            NaN
# 3321453  3408242726       NaN           NaN            NaN
#
#          accrualPeriodicity  accrualPolicy  alternative  audience  available  \
# 0                       NaN            NaN          NaN       NaN        NaN
# 1                       NaN            NaN          NaN       NaN        NaN
# 2                       NaN            NaN          NaN       NaN        NaN
# 3                       NaN            NaN          NaN       NaN        NaN
# 4                       NaN            NaN          NaN       NaN        NaN
# ...                     ...            ...          ...       ...        ...
# 3321449                 NaN            NaN          NaN       NaN        NaN
# 3321450                 NaN            NaN          NaN       NaN        NaN
# 3321451                 NaN            NaN          NaN       NaN        NaN
# 3321452                 NaN            NaN          NaN       NaN        NaN
# 3321453                 NaN            NaN          NaN       NaN        NaN
#
#          bibliographicCitation  ...  level0Gid     level0Name  level1Gid  \
# 0                          NaN  ...        USA  United States    USA.5_1
# 1                          NaN  ...        USA  United States   USA.10_1
# 2                          NaN  ...        USA  United States    USA.5_1
# 3                          NaN  ...        USA  United States   USA.11_1
# 4                          NaN  ...        USA  United States   USA.44_1
# ...                        ...  ...        ...            ...        ...
# 3321449                    NaN  ...        USA  United States    USA.5_1
# 3321450                    NaN  ...        USA  United States   USA.44_1
# 3321451                    NaN  ...        USA  United States    USA.5_1
# 3321452                    NaN  ...        USA  United States   USA.51_1
# 3321453                    NaN  ...        USA  United States   USA.23_1
#
#          level1Name     level2Gid       level2Name  level3Gid  level3Name  \
# 0        California    USA.5.56_1          Ventura        NaN         NaN
# 1           Florida   USA.10.28_1     Hillsborough        NaN         NaN
# 2        California    USA.5.40_1  San Luis Obispo        NaN         NaN
# 3           Georgia   USA.11.44_1           DeKalb        NaN         NaN
# 4             Texas  USA.44.152_1          Lubbock        NaN         NaN
# ...             ...           ...              ...        ...         ...
# 3321449  California    USA.5.39_1      San Joaquin        NaN         NaN
# 3321450       Texas  USA.44.246_1       Williamson        NaN         NaN
# 3321451  California    USA.5.30_1           Orange        NaN         NaN
# 3321452     Wyoming   USA.51.20_1            Teton        NaN         NaN
# 3321453    Michigan   USA.23.85_1        Washtenaw        NaN         NaN
#
#          iucnRedListCategory  eventType
# 0                         NE        NaN
# 1                         NE        NaN
# 2                         LC        NaN
# 3                         NE        NaN
# 4                         LC        NaN
# ...                      ...        ...
# 3321449                   LC        NaN
# 3321450                   LC        NaN
# 3321451                   NE        NaN
# 3321452                   LC        NaN
# 3321453                   LC        NaN
#
# [3321454 rows x 259 columns]

# %%
df_inat['taxonID'].nunique()
# Out:
# 49685

# %%
rel_columns_iNat = [
    'taxonID',
    'taxonKey',
    'countryCode',
    'stateProvince',
    'decimalLatitude',
    'decimalLongitude',
    'eventDate',
    'acceptedScientificName',
    'scientificName',
]
rel_columns_eBird = [
    'TAXON CONCEPT ID',
    'OBSERVATION COUNT',
    'COUNTRY',
    'STATE',
    'LATITUDE',
    'LONGITUDE',
    'OBSERVATION DATE',
    'SCIENTIFIC NAME',
]

# %%
df_iNat2 = df_inat[rel_columns_iNat].copy()
df_eBird2 = df_eBird[rel_columns_eBird].copy()

# %%
df_iNat2.head()
# Out:
#   taxonID   taxonKey countryCode stateProvince  decimalLatitude  \
# 0  123045  2515238.0          US    California        34.140209
# 1   84994  5156078.0          US       Florida        28.059126
# 2   36204  2451234.0          US    California        35.271399
# 3   53326  3169708.0          US       Georgia        33.769633
# 4    9176  5231132.0          US         Texas        33.562034
#
#   decimalLongitude            eventDate  \
# 0      -119.187897  2019-01-30T09:59:56
# 1       -82.418194  2019-01-21T14:35:00
# 2      -120.888941  2019-03-17T13:56:00
# 3        -84.30645  2019-03-29T14:33:23
# 4      -101.809798  2019-04-02T12:44:00
#
#                          acceptedScientificName  \
# 0                       Puccinia evadens Harkn.
# 1           Acanthocephala declivis (Say, 1832)
# 2  Sceloporus occidentalis Baird & Girard, 1852
# 3                                Vinca major L.
# 4    Zonotrichia leucophrys (J.R.Forster, 1772)
#
#                                  scientificName
# 0                       Puccinia evadens Harkn.
# 1           Acanthocephala declivis (Say, 1832)
# 2  Sceloporus occidentalis Baird & Girard, 1852
# 3                                Vinca major L.
# 4    Zonotrichia leucophrys (J.R.Forster, 1772)

# %%
df_iNat2['countryCode'].value_counts()
# Out:
# US    3321452
# Name: countryCode, dtype: int64

# %% [markdown]
# # eBird Analysis

# %%
df_eBird2['COUNTRY'].value_counts()
# Out:
# United States    8694926
# Name: COUNTRY, dtype: int64

# %%
df_eBird2['STATE'].value_counts()
# Out:
# California    8694926
# Name: STATE, dtype: int64

# %%
df_eBird2.head()
# Out:
#    TAXON CONCEPT ID OBSERVATION COUNT        COUNTRY       STATE   LATITUDE  \
# 0  avibase-CA08045E                 1  United States  California  37.892331
# 1  avibase-CA08045E                 X  United States  California  37.871270
# 2  avibase-CA08045E                 1  United States  California  37.834029
# 3  avibase-CA08045E                 1  United States  California  37.695328
# 4  avibase-CA08045E                 1  United States  California  37.834029
#
#     LONGITUDE OBSERVATION DATE SCIENTIFIC NAME
# 0 -122.311800       2019-01-13   Accipiter sp.
# 1 -122.307890       2019-01-01   Accipiter sp.
# 2 -122.238747       2019-01-25   Accipiter sp.
# 3 -121.844741       2019-01-10   Accipiter sp.
# 4 -122.238747       2019-01-25   Accipiter sp.

# %%
df_eBird2['AVIBASEID'] = df_eBird2['TAXON CONCEPT ID'].apply(lambda x : x[-8:])

# %%
df_eBird2
# Out:
#          TAXON CONCEPT ID OBSERVATION COUNT        COUNTRY       STATE  \
# 0        avibase-CA08045E                 1  United States  California
# 1        avibase-CA08045E                 X  United States  California
# 2        avibase-CA08045E                 1  United States  California
# 3        avibase-CA08045E                 1  United States  California
# 4        avibase-CA08045E                 1  United States  California
# ...                   ...               ...            ...         ...
# 8694921  avibase-BC5A9498                13  United States  California
# 8694922  avibase-BC5A9498                 4  United States  California
# 8694923  avibase-BC5A9498                 4  United States  California
# 8694924  avibase-BC5A9498                 4  United States  California
# 8694925  avibase-BC5A9498                17  United States  California
#
#           LATITUDE   LONGITUDE OBSERVATION DATE     SCIENTIFIC NAME AVIBASEID
# 0        37.892331 -122.311800       2019-01-13       Accipiter sp.  CA08045E
# 1        37.871270 -122.307890       2019-01-01       Accipiter sp.  CA08045E
# 2        37.834029 -122.238747       2019-01-25       Accipiter sp.  CA08045E
# 3        37.695328 -121.844741       2019-01-10       Accipiter sp.  CA08045E
# 4        37.834029 -122.238747       2019-01-25       Accipiter sp.  CA08045E
# ...            ...         ...              ...                 ...       ...
# 8694921  39.427357 -121.130547       2019-12-26  Setophaga coronata  BC5A9498
# 8694922  39.189706 -121.593404       2019-12-19  Setophaga coronata  BC5A9498
# 8694923  39.264460 -121.602397       2019-12-19  Setophaga coronata  BC5A9498
# 8694924  39.264460 -121.602397       2019-12-19  Setophaga coronata  BC5A9498
# 8694925  39.265221 -121.534367       2019-12-20  Setophaga coronata  BC5A9498
#
# [8694926 rows x 9 columns]

# %%
df_eBird_median_by_species = df_eBird2[df_eBird2['OBSERVATION COUNT']!='X'].groupby('AVIBASEID')['OBSERVATION COUNT'].median().to_dict()

# %%
df_eBird2['OBSCOUNT'] = df_eBird2[['AVIBASEID','OBSERVATION COUNT']].apply(
    lambda row: (df_eBird_median_by_species[row['AVIBASEID']] if row['AVIBASEID'] in df_eBird_median_by_species else 1) if row['OBSERVATION COUNT'] == 'X' else row['OBSERVATION COUNT'],
    axis=1
)

# %%
df_eBird2.shape
# Out:
# (8694926, 10)

# %%
df_eBird2['OBSCOUNT'] = df_eBird2['OBSCOUNT'].astype(float)

# %%
df_eBird2['OBSCOUNT'].sum()
# Out:
# 255405907.5

# %%
df_eBird2['AVIBASEID'].nunique()
# Out:
# 1088

# %%
df_eBird3 = df_eBird2[
    (df_eBird2['LATITUDE']>=36.4701132878)
    &
    (df_eBird2['LATITUDE']<=42.009518)
    &
    (df_eBird2['LONGITUDE']>= -124.409591)
    &
    (df_eBird2['LONGITUDE']<= -114.131211)
].copy()

# %%
df_eBird3.shape
# Out:
# (5168169, 10)

# %%
df_eBird3['OBSCOUNT'].sum()
# Out:
# 218303859.5

# %%
df_eBird3['AVIBASEID'].nunique()
# Out:
# 918

# %%
df_eBird3['observation_datetime'] = pd.to_datetime(df_eBird3['OBSERVATION DATE'])

# %%
df_eBird3['WEEK'] = df_eBird3['observation_datetime'].dt.week
# Out:
# /var/folders/ms/2ygwp03d4b5526gc0h51spqh0000gn/T/ipykernel_5100/4278245370.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df_eBird3['WEEK'] = df_eBird3['observation_datetime'].dt.week

# %%
df_eBird3['YEAR'] = df_eBird3['observation_datetime'].dt.year

# %%
df_eBird3['YEAR'].value_counts()
# Out:
# 2019    5168169
# Name: YEAR, dtype: int64

# %% [markdown]
# # iNat Analysis

# %%
df_inat.shape
# Out:
# (3321454, 259)

# %%
df_iNat2.shape
# Out:
# (3321454, 9)

# %%
df_iNat2.head()
# Out:
#   taxonID   taxonKey countryCode stateProvince  decimalLatitude  \
# 0  123045  2515238.0          US    California        34.140209
# 1   84994  5156078.0          US       Florida        28.059126
# 2   36204  2451234.0          US    California        35.271399
# 3   53326  3169708.0          US       Georgia        33.769633
# 4    9176  5231132.0          US         Texas        33.562034
#
#   decimalLongitude            eventDate  \
# 0      -119.187897  2019-01-30T09:59:56
# 1       -82.418194  2019-01-21T14:35:00
# 2      -120.888941  2019-03-17T13:56:00
# 3        -84.30645  2019-03-29T14:33:23
# 4      -101.809798  2019-04-02T12:44:00
#
#                          acceptedScientificName  \
# 0                       Puccinia evadens Harkn.
# 1           Acanthocephala declivis (Say, 1832)
# 2  Sceloporus occidentalis Baird & Girard, 1852
# 3                                Vinca major L.
# 4    Zonotrichia leucophrys (J.R.Forster, 1772)
#
#                                  scientificName
# 0                       Puccinia evadens Harkn.
# 1           Acanthocephala declivis (Say, 1832)
# 2  Sceloporus occidentalis Baird & Girard, 1852
# 3                                Vinca major L.
# 4    Zonotrichia leucophrys (J.R.Forster, 1772)

# %%
df_iNat2['countryCode'].value_counts()
# Out:
# US    3321452
# Name: countryCode, dtype: int64

# %%
df_iNat2['stateProvince'].value_counts()
# Out:
# California              717224
# Texas                   491869
# Florida                 182561
# New York                138104
# Ohio                    111734
# Virginia                 88869
# Massachusetts            87683
# Illinois                 87369
# Pennsylvania             84083
# North Carolina           80368
# Arizona                  77953
# Oregon                   69151
# Washington               67702
# Maryland                 66009
# New Jersey               64479
# Vermont                  59887
# Colorado                 57119
# Michigan                 54503
# Minnesota                50984
# New Mexico               49280
# Alabama                  45433
# Tennessee                44713
# Wisconsin                43611
# Georgia                  34427
# Louisiana                32647
# Indiana                  28997
# South Carolina           27786
# Missouri                 26843
# Kentucky                 25402
# Arkansas                 24412
# Oklahoma                 23415
# Maine                    23354
# Mississippi              22729
# Utah                     21369
# Connecticut              21068
# Alaska                   19832
# Nevada                   19293
# Hawaii                   18744
# Kansas                   18147
# New Hampshire            17578
# Idaho                    12941
# Montana                  11514
# District of Columbia     10677
# West Virginia            10227
# Nebraska                  9273
# Iowa                      9083
# Delaware                  8260
# Wyoming                   8100
# Rhode Island              4286
# North Dakota              4128
# South Dakota              3439
# Midway                       2
# ACCEPTED                     1
# Name: stateProvince, dtype: int64

# %%
df_iNat2['observation_dt'] = pd.to_datetime(df_iNat2['eventDate'])

# %%
df_iNat3 = df_iNat2[df_iNat2['stateProvince'] == 'California'].copy()

# %%
df_iNat3
# Out:
#          taxonID   taxonKey countryCode stateProvince  decimalLatitude  \
# 0         123045  2515238.0          US    California        34.140209
# 2          36204  2451234.0          US    California        35.271399
# 7          58088  3051417.0          US    California        33.069050
# 11         58976  2927694.0          US    California        39.780938
# 12         42391  2441119.0          US    California        33.875304
# ...          ...        ...         ...           ...              ...
# 3321414     9535  9596413.0          US    California        34.117050
# 3321415   485176  2498155.0          US    California        37.582335
# 3321417  1061811  5955209.0          US    California        37.047745
# 3321449   508048  9036008.0          US    California        38.157721
# 3321451   564394  2498314.0          US    California        33.704197
#
#         decimalLongitude            eventDate  \
# 0            -119.187897  2019-01-30T09:59:56
# 2            -120.888941  2019-03-17T13:56:00
# 7            -116.601188  2019-04-18T09:14:00
# 11           -121.730509  2019-04-28T12:28:00
# 12            -116.10492  2019-05-02T10:44:57
# ...                  ...                  ...
# 3321414      -117.965894  2019-01-04T16:42:00
# 3321415      -122.314627  2019-02-09T07:46:00
# 3321417      -122.202159  2019-04-07T12:43:17
# 3321449      -121.443274  2019-12-16T16:59:00
# 3321451      -118.004519  2019-12-17T15:20:00
#
#                                  acceptedScientificName  \
# 0                               Puccinia evadens Harkn.
# 2          Sceloporus occidentalis Baird & Girard, 1852
# 7                          Thysanocarpus curvipes Hook.
# 11           Navarretia pubescens (Benth.) Hook. & Arn.
# 12                           Ovis canadensis Shaw, 1804
# ...                                                 ...
# 3321414                Sturnella neglecta Audubon, 1844
# 3321415                     Anas americana Gmelin, 1789
# 3321417  Porpolomopsis calyptriformis (Berk.) Bresinsky
# 3321449                Grus canadensis (Linnaeus, 1758)
# 3321451                           Mareca Stephens, 1824
#
#                                          scientificName      observation_dt
# 0                               Puccinia evadens Harkn. 2019-01-30 09:59:56
# 2          Sceloporus occidentalis Baird & Girard, 1852 2019-03-17 13:56:00
# 7                          Thysanocarpus curvipes Hook. 2019-04-18 09:14:00
# 11           Navarretia pubescens (Benth.) Hook. & Arn. 2019-04-28 12:28:00
# 12                           Ovis canadensis Shaw, 1804 2019-05-02 10:44:57
# ...                                                 ...                 ...
# 3321414                Sturnella neglecta Audubon, 1844 2019-01-04 16:42:00
# 3321415                 Mareca americana (Gmelin, 1789) 2019-02-09 07:46:00
# 3321417  Porpolomopsis calyptriformis (Berk.) Bresinsky 2019-04-07 12:43:17
# 3321449            Antigone canadensis (Linnaeus, 1758) 2019-12-16 16:59:00
# 3321451                           Mareca Stephens, 1824 2019-12-17 15:20:00
#
# [717224 rows x 10 columns]

# %%
df_iNat3['decimalLatitude'] = df_iNat3['decimalLatitude'].astype(float)

# %%
df_iNat3['decimalLongitude'] = df_iNat3['decimalLongitude'].astype(float)

# %%
df_iNat4 = df_iNat3[
    (df_iNat3['decimalLatitude']>=36.4701132878)
    &
    (df_iNat3['decimalLatitude']<=42.009518)
    &
    (df_iNat3['decimalLongitude']>= -124.409591)
    &
    (df_iNat3['decimalLongitude']<= -114.131211)
].copy()

# %%
df_iNat4.shape
# Out:
# (363386, 10)

# %%
df_iNat4['YEAR'] = df_iNat4['observation_dt'].dt.year
df_iNat4['WEEK'] = df_iNat4['observation_dt'].dt.week
# Out:
# /var/folders/ms/2ygwp03d4b5526gc0h51spqh0000gn/T/ipykernel_5100/2813681667.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df_iNat4['WEEK'] = df_iNat4['observation_dt'].dt.week

# %%
df_iNat4['YEAR'].value_counts()
# Out:
# 2019    363386
# Name: YEAR, dtype: int64

# %%
df_iNat4['taxonID'].nunique()
# Out:
# 10757

# %% [markdown]
# # Merging iNat and eBird

# %%
df_tax_key = pd.read_csv('../data/query_taxonIDs_various.csv')
# Out:
# /var/folders/ms/2ygwp03d4b5526gc0h51spqh0000gn/T/ipykernel_5100/2743186917.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_tax_key = pd.read_csv('../data/query_taxonIDs_various.csv')

# %%
df_tax_key.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 830987 entries, 0 to 830986
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   item       830987 non-null  object
#  1   iNat_Tid   830987 non-null  object
#  2   ITIS_TSN   314392 non-null  float64
#  3   GBF_ID     809035 non-null  float64
#  4   avibaseid  8795 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 31.7+ MB

# %% [markdown]
# # Adding avibase-id to iNat

# %%
df_tax_key_fil = df_tax_key[~df_tax_key['avibaseid'].isna()]

# %%
df_tax_key_fil = df_tax_key_fil[df_tax_key_fil['iNat_Tid']!='Frank'].copy()

# %%
df_tax_key_fil['iNat_Tid_num']= df_tax_key_fil['iNat_Tid'].astype(float)

# %%
df_tax_key_fil
# Out:
#                                             item   iNat_Tid  ITIS_TSN  \
# 8         http://www.wikidata.org/entity/Q855024       2244  554655.0
# 10         http://www.wikidata.org/entity/Q25388     204556  561707.0
# 19       http://www.wikidata.org/entity/Q1094736       3352  676921.0
# 23        http://www.wikidata.org/entity/Q961967       2021  553828.0
# 24        http://www.wikidata.org/entity/Q494983         26  176186.0
# ...                                          ...        ...       ...
# 823400  http://www.wikidata.org/entity/Q55112126    1286936       NaN
# 824753    http://www.wikidata.org/entity/Q971542     792908  554011.0
# 827782  http://www.wikidata.org/entity/Q27617614     718627  918391.0
# 829307  http://www.wikidata.org/entity/Q28065684     979640       NaN
# 829702   http://www.wikidata.org/entity/Q1591239  138481918  559668.0
#
#             GBF_ID         avibaseid  iNat_Tid_num
# 8        2475439.0  302385236F22586B        2244.0
# 10       2488949.0  EBDD410629FE11AC      204556.0
# 19       2495757.0  F6C3F6DB6EE1478B        3352.0
# 23       2482140.0  69BBDE320D31CA7A        2021.0
# 24       2474943.0  38F36091DBC85095          26.0
# ...            ...               ...           ...
# 823400   7626227.0          3C6A0512     1286936.0
# 824753   2478391.0  33F13BB178A3EB73      792908.0
# 827782   6541423.0  0CC1FD4A59962145      718627.0
# 829307  10658506.0  3FC8CA50CC50BAAD      979640.0
# 829702   2492428.0  2A6075392F255EB8   138481918.0
#
# [8794 rows x 6 columns]

# %%
merge_process1 = df_iNat4.merge(right=df_tax_key_fil, how='left', left_on='taxonID', right_on='iNat_Tid_num')

# %%
merge_process2 = [x[0:8] for x in merge_process1['avibaseid'].dropna().values]

# %%
merge_process3 = list(set(merge_process2))

# %%
merge_process3
# Out:
# ['8F123A11',
#  'FC366114',
#  '466E9077',
#  '018B3169',
#  'F35821AA',
#  '7E327303',
#  '2B46719D',
#  '8D6D5F2B',
#  '28A4DA76',
#  '8DB64266',
#  'BBA263C2',
#  '0B0BC750',
#  '32DCEC14',
#  '76DF73A9',
#  '4E192262',
#  '5284C27B',
#  '029491CD',
#  'B59E1863',
#  '42393721',
#  'E366AB90',
#  '0B1B2EB6',
#  'B745D852',
#  '603194D3',
#  '93013964',
#  '60E6081E',
#  '4A3B2CFF',
#  '891798D9',
#  '36B3872D',
#  '78509A5D',
#  'B6B84BEE',
#  '4185F617',
#  '11CF8C9A',
#  '938C5572',
#  '9A684C99',
#  '6C74415D',
#  'F59AB6B3',
#  '77AFF9B8',
#  '67CEA1C1',
#  'D4540F88',
#  '6A7F76A7',
#  '1FFFEF4E',
#  'A8C34DC9',
#  '7E65A952',
#  'DDAF0666',
#  '2FA39DCD',
#  'D13B9122',
#  '6FB34E54',
#  'ED4CE8E7',
#  '97B870B4',
#  '7E022378',
#  '319D044A',
#  '862DF149',
#  '23863F65',
#  'F012ED4B',
#  '41062654',
#  'ACB9D1C6',
#  'C5DF08E7',
#  'B86C504C',
#  'FB4D08F0',
#  'D201EB72',
#  '39BD9FF2',
#  '5CBA3391',
#  'C53F4940',
#  '4D207AF6',
#  '3558066B',
#  '9BEECB7E',
#  'F9305BAA',
#  'BD49DB46',
#  'DA2F24E3',
#  '1181E297',
#  '20748450',
#  '154BCCAE',
#  '536A5157',
#  '0BDB87DE',
#  '9C5ED06A',
#  '6BB94D7E',
#  '866903B9',
#  '37E9CCDA',
#  '85625D75',
#  '15EE0D36',
#  '07C11CF3',
#  '2F5DF476',
#  'DB5DABCF',
#  '4AED44E8',
#  'D204A930',
#  '6CDC3C9C',
#  'B12B8816',
#  '00124D98',
#  'BDC5CF80',
#  '2E047850',
#  '90E2543E',
#  '8C4CE60F',
#  '95E28A57',
#  'C25794D5',
#  '0A4609D1',
#  '3E2D0C9B',
#  '5EC21767',
#  '6D4F72B1',
#  '56036504',
#  '8EB0C1FA',
#  '5459228D',
#  '9BE68BD3',
#  'F6C6C3F7',
#  '58312873',
#  '9A77D2B0',
#  'BC5A9498',
#  '0ADA5F17',
#  'F3DA111C',
#  '08F22F84',
#  '1F1AD154',
#  '4F28673C',
#  '13E9F9B4',
#  '0413ED30',
#  '1BB9C864',
#  'FA36ABE5',
#  '188707A5',
#  '734C73A9',
#  '00635FF9',
#  '25ACCDC0',
#  '68EDCC23',
#  '4AAEF549',
#  '6EB81C98',
#  '3072CC16',
#  'BC06BC0D',
#  '9B26D30B',
#  'DC3050A9',
#  '824361E5',
#  '18A19380',
#  'B9B272F4',
#  '25C94A8F',
#  '12D5BA6C',
#  'A2BB98A9',
#  '5F8E7CA8',
#  '3E04020B',
#  '75DC49AD',
#  '989B57D8',
#  'BD61BDEC',
#  '1456993D',
#  'D3A260BC',
#  '1929E1E1',
#  'CD7DC84B',
#  'B77377EE',
#  '24111FA5',
#  'BCF9A19A',
#  '49025D8B',
#  'BDBB04D5',
#  '87878948',
#  '3A3C62BC',
#  '709AF716',
#  'BD0914CB',
#  '1E1AB415',
#  '3647E146',
#  'EA5E858A',
#  '0C120038',
#  '3EF081A8',
#  'B01E8BD4',
#  '407E2CA8',
#  '93694BB5',
#  'C6772490',
#  'C7F1C08C',
#  '544A5E6B',
#  '1E82CE1E',
#  '7EFF698D',
#  '8B85CB2C',
#  'A0F29F1E',
#  '115F04DD',
#  '4FF7DE80',
#  'EB0CD5DC',
#  '31FB19D4',
#  'BBFF0963',
#  '6BDADC9C',
#  'B7D7EF23',
#  'C6E1197B',
#  'BE78E765',
#  'AC2B812A',
#  '86182656',
#  '50566E50',
#  'F6DF700B',
#  '649F85B5',
#  'AA7901D8',
#  '58C502EA',
#  '6C439FF4',
#  '62CA2AF8',
#  '11512CF4',
#  '3230898E',
#  '2CC21529',
#  'B48335B1',
#  '49D9148A',
#  '2DABF98F',
#  'CEA5B6AA',
#  'DACF7A98',
#  'A6905B3C',
#  '9E9F2476',
#  'D05FFEF7',
#  'C27D9E26',
#  'E36325FA',
#  '62DAF6CC',
#  '6996D540',
#  'DE0971C1',
#  '83F9C058',
#  '538A9CA7',
#  'E0148AC5',
#  '56CCA717',
#  '13854B6E',
#  '1CBD2CED',
#  '98FB6D4B',
#  '951C150C',
#  'B5CE8FAD',
#  'E53FC25C',
#  'FB738385',
#  '31ACA998',
#  '20C2214E',
#  '031409C7',
#  '26BA25EF',
#  'B9EE9676',
#  'F8DDF6A6',
#  'E4B3332D',
#  '5BFFE091',
#  '667AE65A',
#  '240E3390',
#  'BBA2F9DF',
#  '1F9D883E',
#  'F93AC929',
#  'EAD14427',
#  'EB98812F',
#  '27903EF7',
#  '0D88C072',
#  '8601A467',
#  'F002188E',
#  '9F67F3AF',
#  'FC4D40D2',
#  '9437D635',
#  '171E91FF',
#  '1E1B6D19',
#  '36171C2B',
#  '5816834E',
#  'CB343E43',
#  '91CCBC71',
#  'E0A04985',
#  '06B9BD24',
#  'C9ABA616',
#  '95B77F08',
#  '96B91A68',
#  'A47B0BD4',
#  '0337440E',
#  '7A24F57F',
#  'F5C8516D',
#  'FED3756C',
#  'E196D6F9',
#  '667C6969',
#  '135564AA',
#  '6C50988A',
#  'BD929CBC',
#  'AF0C7BDE',
#  '486265CF',
#  '7CB8F5B7',
#  '575A3E3B',
#  '31557374',
#  '0EB30FB8',
#  'F7937349',
#  '90B13ACF',
#  '53D94597',
#  '1F09CCCC',
#  '0E599E6C',
#  '4D2FF6F1',
#  '534FB490',
#  '1725B07D',
#  '77567086',
#  'A15C5071',
#  '7FCE8A43',
#  'E6F3BA54',
#  '9456DEDF',
#  '4BB4F257',
#  'D621FFC6',
#  'E7C9A1F5',
#  '526A3692',
#  '0BCBA6B9',
#  'EE8ECB1D',
#  '3AC46C54',
#  'A5EC8BF5',
#  '2281F1C7',
#  '75600969',
#  '930E8874',
#  '9FFEDE99',
#  '68EA281A',
#  '4A5B4883',
#  '4D4ED4BD',
#  '01060BFD',
#  '6B7A93C5',
#  '7AB1229B',
#  'B1F0CC82',
#  'E19252A7',
#  '9DBB70D5',
#  'CAA5E106',
#  '46B54DB1',
#  'C3168495',
#  'B401C2DD',
#  'B182DED2',
#  '420850D6',
#  'EA4D6C0B',
#  '2CF6D6F6',
#  '043F337A',
#  '45D829B3',
#  'ECDE73F2',
#  '52F63879',
#  '9BEBC025',
#  '0783A7EA',
#  '7B0669CB',
#  'A1F323F5',
#  'FD2B0309',
#  'BB6B236F',
#  '6D2B5CDA',
#  'BCBD2EAE',
#  'ACC99F35',
#  'C5971E25',
#  '86D45B8F',
#  '24E39ACD',
#  'B7E467E2',
#  '03AC32BA',
#  'FF592882',
#  '79F3C681',
#  'E7A14E91',
#  '85106518',
#  '8F268682',
#  '15369E8E',
#  'BAC33609',
#  '5BC4E0EF',
#  '0EB07C12',
#  'BA4C8A02',
#  'AC1E519F',
#  '178B8955',
#  'E1714A09',
#  '1EB2595E',
#  '63FB826E',
#  '0716A71C',
#  'AF49F890',
#  'BA9191BC',
#  '24F14328',
#  'B7B1A5DD',
#  '2225D685',
#  '1044B438',
#  'F8AFCAC7',
#  '89F8B6F5',
#  'A091D50A',
#  '3F9E1C51',
#  'A59FA446',
#  '640D71AA',
#  '41FACE63',
#  '19CCBBD2',
#  '049D9AEA',
#  'F577BA0F',
#  'FFF61080',
#  'F5C181CA',
#  '88AB027C',
#  'F6CA75F0',
#  '7784B060',
#  '12E354E2',
#  '115AF02D',
#  '87705CC4',
#  '28669A3D',
#  '787E0536',
#  '075C1610',
#  '145F1116',
#  '4168AF09',
#  'C235A4D7',
#  '39F29B55',
#  'A7A75EA1',
#  'F5837054',
#  '94A44032',
#  '89431E9F',
#  'F3BEE8C7',
#  '249AE8DF',
#  '2C7A2673',
#  'AB1CB216',
#  '1DA430B8',
#  '151C2B3F',
#  '624078BA',
#  '27B2749A',
#  '39086887',
#  '694C127A',
#  '9690689D',
#  '80285D5C',
#  'A5F09E05',
#  'E4A5B66A',
#  '31CE00C7',
#  '000482C9',
#  '295C4CD6',
#  '87CBEBF7',
#  '9A8E55D0',
#  'B4EE123D',
#  'DE473F42',
#  '60214D49']

# %%
len(merge_process3)
# Out:
# 392

# %%
len(merge_process3)
# Out:
# 392

# %%
df_eBird3
# Out:
#          TAXON CONCEPT ID OBSERVATION COUNT        COUNTRY       STATE  \
# 0        avibase-CA08045E                 1  United States  California
# 1        avibase-CA08045E                 X  United States  California
# 2        avibase-CA08045E                 1  United States  California
# 3        avibase-CA08045E                 1  United States  California
# 4        avibase-CA08045E                 1  United States  California
# ...                   ...               ...            ...         ...
# 8694921  avibase-BC5A9498                13  United States  California
# 8694922  avibase-BC5A9498                 4  United States  California
# 8694923  avibase-BC5A9498                 4  United States  California
# 8694924  avibase-BC5A9498                 4  United States  California
# 8694925  avibase-BC5A9498                17  United States  California
#
#           LATITUDE   LONGITUDE OBSERVATION DATE     SCIENTIFIC NAME AVIBASEID  \
# 0        37.892331 -122.311800       2019-01-13       Accipiter sp.  CA08045E
# 1        37.871270 -122.307890       2019-01-01       Accipiter sp.  CA08045E
# 2        37.834029 -122.238747       2019-01-25       Accipiter sp.  CA08045E
# 3        37.695328 -121.844741       2019-01-10       Accipiter sp.  CA08045E
# 4        37.834029 -122.238747       2019-01-25       Accipiter sp.  CA08045E
# ...            ...         ...              ...                 ...       ...
# 8694921  39.427357 -121.130547       2019-12-26  Setophaga coronata  BC5A9498
# 8694922  39.189706 -121.593404       2019-12-19  Setophaga coronata  BC5A9498
# 8694923  39.264460 -121.602397       2019-12-19  Setophaga coronata  BC5A9498
# 8694924  39.264460 -121.602397       2019-12-19  Setophaga coronata  BC5A9498
# 8694925  39.265221 -121.534367       2019-12-20  Setophaga coronata  BC5A9498
#
#          OBSCOUNT observation_datetime  WEEK  YEAR
# 0             1.0           2019-01-13     2  2019
# 1             1.0           2019-01-01     1  2019
# 2             1.0           2019-01-25     4  2019
# 3             1.0           2019-01-10     2  2019
# 4             1.0           2019-01-25     4  2019
# ...           ...                  ...   ...   ...
# 8694921      13.0           2019-12-26    52  2019
# 8694922       4.0           2019-12-19    51  2019
# 8694923       4.0           2019-12-19    51  2019
# 8694924       4.0           2019-12-19    51  2019
# 8694925      17.0           2019-12-20    51  2019
#
# [5168169 rows x 13 columns]

# %%
final_list_birds = [x for x in df_eBird3['AVIBASEID'] if x in merge_process3]

# %%
final_list_birds2_l = list(set(final_list_birds))
final_list_birds2_s = set(final_list_birds)

# %%
len(final_list_birds2_l)
# Out:
# 353

# %% [markdown]
# # Filtering only the relevant birds

# %%
df_eBird4 = df_eBird3[df_eBird3['AVIBASEID'].isin(final_list_birds2_s)]

# %%
df_eBird4.shape
# Out:
# (3842332, 13)

# %%
df_eBird4['OBSCOUNT'].sum()
# Out:
# 187133113.0

# %%
df_eBird4['AVIBASEID'].nunique()
# Out:
# 353

# %%
df_eBird4
# Out:
#          TAXON CONCEPT ID OBSERVATION COUNT        COUNTRY       STATE  \
# 6        avibase-7E327303                10  United States  California
# 7        avibase-7E327303                 1  United States  California
# 8        avibase-7E327303                 3  United States  California
# 9        avibase-7E327303                 1  United States  California
# 10       avibase-7E327303                 2  United States  California
# ...                   ...               ...            ...         ...
# 8694921  avibase-BC5A9498                13  United States  California
# 8694922  avibase-BC5A9498                 4  United States  California
# 8694923  avibase-BC5A9498                 4  United States  California
# 8694924  avibase-BC5A9498                 4  United States  California
# 8694925  avibase-BC5A9498                17  United States  California
#
#           LATITUDE   LONGITUDE OBSERVATION DATE          SCIENTIFIC NAME  \
# 6        37.606181 -121.735039       2019-01-23  Melanerpes formicivorus
# 7        37.866130 -122.239573       2019-01-12  Melanerpes formicivorus
# 8        37.863654 -122.244400       2019-01-13  Melanerpes formicivorus
# 9        37.890680 -122.271627       2019-01-04  Melanerpes formicivorus
# 10       37.601176 -121.699676       2019-01-10  Melanerpes formicivorus
# ...            ...         ...              ...                      ...
# 8694921  39.427357 -121.130547       2019-12-26       Setophaga coronata
# 8694922  39.189706 -121.593404       2019-12-19       Setophaga coronata
# 8694923  39.264460 -121.602397       2019-12-19       Setophaga coronata
# 8694924  39.264460 -121.602397       2019-12-19       Setophaga coronata
# 8694925  39.265221 -121.534367       2019-12-20       Setophaga coronata
#
#         AVIBASEID  OBSCOUNT observation_datetime  WEEK  YEAR
# 6        7E327303      10.0           2019-01-23     4  2019
# 7        7E327303       1.0           2019-01-12     2  2019
# 8        7E327303       3.0           2019-01-13     2  2019
# 9        7E327303       1.0           2019-01-04     1  2019
# 10       7E327303       2.0           2019-01-10     2  2019
# ...           ...       ...                  ...   ...   ...
# 8694921  BC5A9498      13.0           2019-12-26    52  2019
# 8694922  BC5A9498       4.0           2019-12-19    51  2019
# 8694923  BC5A9498       4.0           2019-12-19    51  2019
# 8694924  BC5A9498       4.0           2019-12-19    51  2019
# 8694925  BC5A9498      17.0           2019-12-20    51  2019
#
# [3842332 rows x 13 columns]

# %%
df_iNat4
# Out:
#          taxonID   taxonKey countryCode stateProvince  decimalLatitude  \
# 11         58976  2927694.0          US    California        39.780938
# 13         52155  2183465.0          US    California        37.942774
# 14          6317  2476674.0          US    California        37.951323
# 17         48225  2888380.0          US    California        37.315917
# 30        113521  1428261.0          US    California        37.746799
# ...          ...        ...         ...           ...              ...
# 3321412    42221  4262326.0          US    California        38.351037
# 3321413    59556  5353595.0          US    California        40.075851
# 3321415   485176  2498155.0          US    California        37.582335
# 3321417  1061811  5955209.0          US    California        37.047745
# 3321449   508048  9036008.0          US    California        38.157721
#
#          decimalLongitude            eventDate  \
# 11            -121.730509  2019-04-28T12:28:00
# 13            -122.349663  2019-05-05T14:01:08
# 14            -122.598442  2019-05-08T07:49:00
# 17            -122.199652  2019-06-01T14:42:03
# 30            -119.550209  2019-09-10T13:17:00
# ...                   ...                  ...
# 3321412       -122.516596  2019-10-14T12:42:00
# 3321413       -121.599233  2019-04-26T03:26:00
# 3321415       -122.314627  2019-02-09T07:46:00
# 3321417       -122.202159  2019-04-07T12:43:17
# 3321449       -121.443274  2019-12-16T16:59:00
#
#                                     acceptedScientificName  \
# 11              Navarretia pubescens (Benth.) Hook. & Arn.
# 13                        Dermacentor variabilis Say, 1821
# 14                           Calypte anna (R.Lesson, 1829)
# 17                          Eschscholzia californica Cham.
# 30                          Sympetrum pallipes Hagen, 1874
# ...                                                    ...
# 3321412  Odocoileus hemionus columbianus (Richardson, 1...
# 3321413                Cercis occidentalis Torr. ex A.Gray
# 3321415                        Anas americana Gmelin, 1789
# 3321417     Porpolomopsis calyptriformis (Berk.) Bresinsky
# 3321449                   Grus canadensis (Linnaeus, 1758)
#
#                                             scientificName  \
# 11              Navarretia pubescens (Benth.) Hook. & Arn.
# 13                        Dermacentor variabilis Say, 1821
# 14                           Calypte anna (R.Lesson, 1829)
# 17                          Eschscholzia californica Cham.
# 30                          Sympetrum pallipes Hagen, 1874
# ...                                                    ...
# 3321412  Odocoileus hemionus columbianus (Richardson, 1...
# 3321413                Cercis occidentalis Torr. ex A.Gray
# 3321415                    Mareca americana (Gmelin, 1789)
# 3321417     Porpolomopsis calyptriformis (Berk.) Bresinsky
# 3321449               Antigone canadensis (Linnaeus, 1758)
#
#              observation_dt  YEAR  WEEK
# 11      2019-04-28 12:28:00  2019    17
# 13      2019-05-05 14:01:08  2019    18
# 14      2019-05-08 07:49:00  2019    19
# 17      2019-06-01 14:42:03  2019    22
# 30      2019-09-10 13:17:00  2019    37
# ...                     ...   ...   ...
# 3321412 2019-10-14 12:42:00  2019    42
# 3321413 2019-04-26 03:26:00  2019    17
# 3321415 2019-02-09 07:46:00  2019     6
# 3321417 2019-04-07 12:43:17  2019    14
# 3321449 2019-12-16 16:59:00  2019    51
#
# [363386 rows x 12 columns]

# %%
df_iNat4
# Out:
#          taxonID   taxonKey countryCode stateProvince  decimalLatitude  \
# 11         58976  2927694.0          US    California        39.780938
# 13         52155  2183465.0          US    California        37.942774
# 14          6317  2476674.0          US    California        37.951323
# 17         48225  2888380.0          US    California        37.315917
# 30        113521  1428261.0          US    California        37.746799
# ...          ...        ...         ...           ...              ...
# 3321412    42221  4262326.0          US    California        38.351037
# 3321413    59556  5353595.0          US    California        40.075851
# 3321415   485176  2498155.0          US    California        37.582335
# 3321417  1061811  5955209.0          US    California        37.047745
# 3321449   508048  9036008.0          US    California        38.157721
#
#          decimalLongitude            eventDate  \
# 11            -121.730509  2019-04-28T12:28:00
# 13            -122.349663  2019-05-05T14:01:08
# 14            -122.598442  2019-05-08T07:49:00
# 17            -122.199652  2019-06-01T14:42:03
# 30            -119.550209  2019-09-10T13:17:00
# ...                   ...                  ...
# 3321412       -122.516596  2019-10-14T12:42:00
# 3321413       -121.599233  2019-04-26T03:26:00
# 3321415       -122.314627  2019-02-09T07:46:00
# 3321417       -122.202159  2019-04-07T12:43:17
# 3321449       -121.443274  2019-12-16T16:59:00
#
#                                     acceptedScientificName  \
# 11              Navarretia pubescens (Benth.) Hook. & Arn.
# 13                        Dermacentor variabilis Say, 1821
# 14                           Calypte anna (R.Lesson, 1829)
# 17                          Eschscholzia californica Cham.
# 30                          Sympetrum pallipes Hagen, 1874
# ...                                                    ...
# 3321412  Odocoileus hemionus columbianus (Richardson, 1...
# 3321413                Cercis occidentalis Torr. ex A.Gray
# 3321415                        Anas americana Gmelin, 1789
# 3321417     Porpolomopsis calyptriformis (Berk.) Bresinsky
# 3321449                   Grus canadensis (Linnaeus, 1758)
#
#                                             scientificName  \
# 11              Navarretia pubescens (Benth.) Hook. & Arn.
# 13                        Dermacentor variabilis Say, 1821
# 14                           Calypte anna (R.Lesson, 1829)
# 17                          Eschscholzia californica Cham.
# 30                          Sympetrum pallipes Hagen, 1874
# ...                                                    ...
# 3321412  Odocoileus hemionus columbianus (Richardson, 1...
# 3321413                Cercis occidentalis Torr. ex A.Gray
# 3321415                    Mareca americana (Gmelin, 1789)
# 3321417     Porpolomopsis calyptriformis (Berk.) Bresinsky
# 3321449               Antigone canadensis (Linnaeus, 1758)
#
#              observation_dt  YEAR  WEEK
# 11      2019-04-28 12:28:00  2019    17
# 13      2019-05-05 14:01:08  2019    18
# 14      2019-05-08 07:49:00  2019    19
# 17      2019-06-01 14:42:03  2019    22
# 30      2019-09-10 13:17:00  2019    37
# ...                     ...   ...   ...
# 3321412 2019-10-14 12:42:00  2019    42
# 3321413 2019-04-26 03:26:00  2019    17
# 3321415 2019-02-09 07:46:00  2019     6
# 3321417 2019-04-07 12:43:17  2019    14
# 3321449 2019-12-16 16:59:00  2019    51
#
# [363386 rows x 12 columns]

# %%
merge_process1.shape
# Out:
# (364365, 18)

# %%
df_iNat5 = merge_process1[~(merge_process1['avibaseid'].isna())].copy()

# %%
df_iNat5['AVIBASEID'] = df_iNat5['avibaseid'].apply(lambda x: x[0:8])

# %%
df_iNat6 = df_iNat5.drop_duplicates().copy()

# %%
df_iNat6
# Out:
#        taxonID   taxonKey countryCode stateProvince  decimalLatitude  \
# 2         6317  2476674.0          US    California        37.951323
# 19        8021  2482507.0          US    California        36.950220
# 20       18209  2478133.0          US    California        37.514882
# 24        4235  2482033.0          US    California        37.973925
# 29        6930  9761484.0          US    California        37.769881
# ...        ...        ...         ...           ...              ...
# 364342    4956  9630752.0          US    California        37.794537
# 364351    9100  2492196.0          US    California        38.552241
# 364354    9185  5231138.0          US    California        37.433635
# 364362  485176  2498155.0          US    California        37.582335
# 364364  508048  9036008.0          US    California        38.157721
#
#         decimalLongitude            eventDate  \
# 2            -122.598442  2019-05-08T07:49:00
# 19           -122.057557  2019-08-23T10:49:00
# 20           -121.831151  2019-01-19T16:51:00
# 24           -121.827973  2019-03-14T11:26:00
# 29           -122.502033  2019-07-09T19:32:00
# ...                  ...                  ...
# 364342       -122.466049  2019-06-07T08:18:57
# 364351       -121.629993  2019-09-14T09:59:00
# 364354       -122.097624  2019-01-10T13:54:00
# 364362       -122.314627  2019-02-09T07:46:00
# 364364       -121.443274  2019-12-16T16:59:00
#
#                             acceptedScientificName  \
# 2                    Calypte anna (R.Lesson, 1829)
# 19           Corvus brachyrhynchos C.L.Brehm, 1822
# 20        Melanerpes formicivorus (Swainson, 1827)
# 24      Aechmophorus occidentalis (Lawrence, 1858)
# 29               Anas platyrhynchos Linnaeus, 1758
# ...                                            ...
# 364342               Ardea herodias Linnaeus, 1758
# 364351          Melospiza melodia (A.Wilson, 1810)
# 364354  Zonotrichia atricapilla (J.F.Gmelin, 1789)
# 364362                 Anas americana Gmelin, 1789
# 364364            Grus canadensis (Linnaeus, 1758)
#
#                                     scientificName      observation_dt  YEAR  \
# 2                    Calypte anna (R.Lesson, 1829) 2019-05-08 07:49:00  2019
# 19           Corvus brachyrhynchos C.L.Brehm, 1822 2019-08-23 10:49:00  2019
# 20        Melanerpes formicivorus (Swainson, 1827) 2019-01-19 16:51:00  2019
# 24      Aechmophorus occidentalis (Lawrence, 1858) 2019-03-14 11:26:00  2019
# 29               Anas platyrhynchos Linnaeus, 1758 2019-07-09 19:32:00  2019
# ...                                            ...                 ...   ...
# 364342               Ardea herodias Linnaeus, 1758 2019-06-07 08:18:57  2019
# 364351          Melospiza melodia (A.Wilson, 1810) 2019-09-14 09:59:00  2019
# 364354  Zonotrichia atricapilla (J.F.Gmelin, 1789) 2019-01-10 13:54:00  2019
# 364362             Mareca americana (Gmelin, 1789) 2019-02-09 07:46:00  2019
# 364364        Antigone canadensis (Linnaeus, 1758) 2019-12-16 16:59:00  2019
#
#         WEEK                                      item iNat_Tid  ITIS_TSN  \
# 2         19    http://www.wikidata.org/entity/Q564265     6317  178036.0
# 19        34    http://www.wikidata.org/entity/Q267735     8021  179731.0
# 20         3    http://www.wikidata.org/entity/Q368657    18209  178189.0
# 24        11    http://www.wikidata.org/entity/Q679154     4235  174503.0
# 29        28     http://www.wikidata.org/entity/Q25348     6930  175063.0
# ...      ...                                       ...      ...       ...
# 364342    23    http://www.wikidata.org/entity/Q333796     4956  174773.0
# 364351    37    http://www.wikidata.org/entity/Q842599     9100  179492.0
# 364354     2    http://www.wikidata.org/entity/Q690956     9185  179461.0
# 364362     6  http://www.wikidata.org/entity/Q28106685   485176  175095.0
# 364364    51  http://www.wikidata.org/entity/Q28114133   508048       NaN
#
#            GBF_ID         avibaseid  iNat_Tid_num AVIBASEID
# 2       2476674.0  423937213450C257        6317.0  42393721
# 19      2482507.0  9E9F24769B6ACBE3        8021.0  9E9F2476
# 20      2478133.0  7E3273031F76242B       18209.0  7E327303
# 24      2482033.0  C6E1197BE78E2E17        4235.0  C6E1197B
# 29      2498132.0  85625D75F2524457        6930.0  85625D75
# ...           ...               ...           ...       ...
# 364342  9630752.0  93694BB5492F7012        4956.0  93694BB5
# 364351  2492196.0  A5F09E0521019564        9100.0  A5F09E05
# 364354  5231138.0  BD61BDEC7D0A1633        9185.0  BD61BDEC
# 364362  2498155.0  D201EB7230F20770      485176.0  D201EB72
# 364364  9036008.0  E196D6F9AB1DFF7E      508048.0  E196D6F9
#
# [78981 rows x 19 columns]

# %%
df_iNat7 = df_iNat6[df_iNat6['AVIBASEID'].isin(final_list_birds2_s)]

# %%
df_iNat7.shape
# Out:
# (71565, 19)

# %%
df_iNat7['AVIBASEID'].nunique()
# Out:
# 353

# %%
df_iNat7['AVIBASEID'].nunique()
# Out:
# 353

# %%
df_eBird4['AVIBASEID'].nunique()
# Out:
# 353

# %%
df_eBird4
# Out:
#          TAXON CONCEPT ID OBSERVATION COUNT        COUNTRY       STATE  \
# 6        avibase-7E327303                10  United States  California
# 7        avibase-7E327303                 1  United States  California
# 8        avibase-7E327303                 3  United States  California
# 9        avibase-7E327303                 1  United States  California
# 10       avibase-7E327303                 2  United States  California
# ...                   ...               ...            ...         ...
# 8694921  avibase-BC5A9498                13  United States  California
# 8694922  avibase-BC5A9498                 4  United States  California
# 8694923  avibase-BC5A9498                 4  United States  California
# 8694924  avibase-BC5A9498                 4  United States  California
# 8694925  avibase-BC5A9498                17  United States  California
#
#           LATITUDE   LONGITUDE OBSERVATION DATE          SCIENTIFIC NAME  \
# 6        37.606181 -121.735039       2019-01-23  Melanerpes formicivorus
# 7        37.866130 -122.239573       2019-01-12  Melanerpes formicivorus
# 8        37.863654 -122.244400       2019-01-13  Melanerpes formicivorus
# 9        37.890680 -122.271627       2019-01-04  Melanerpes formicivorus
# 10       37.601176 -121.699676       2019-01-10  Melanerpes formicivorus
# ...            ...         ...              ...                      ...
# 8694921  39.427357 -121.130547       2019-12-26       Setophaga coronata
# 8694922  39.189706 -121.593404       2019-12-19       Setophaga coronata
# 8694923  39.264460 -121.602397       2019-12-19       Setophaga coronata
# 8694924  39.264460 -121.602397       2019-12-19       Setophaga coronata
# 8694925  39.265221 -121.534367       2019-12-20       Setophaga coronata
#
#         AVIBASEID  OBSCOUNT observation_datetime  WEEK  YEAR
# 6        7E327303      10.0           2019-01-23     4  2019
# 7        7E327303       1.0           2019-01-12     2  2019
# 8        7E327303       3.0           2019-01-13     2  2019
# 9        7E327303       1.0           2019-01-04     1  2019
# 10       7E327303       2.0           2019-01-10     2  2019
# ...           ...       ...                  ...   ...   ...
# 8694921  BC5A9498      13.0           2019-12-26    52  2019
# 8694922  BC5A9498       4.0           2019-12-19    51  2019
# 8694923  BC5A9498       4.0           2019-12-19    51  2019
# 8694924  BC5A9498       4.0           2019-12-19    51  2019
# 8694925  BC5A9498      17.0           2019-12-20    51  2019
#
# [3842332 rows x 13 columns]

# %%
df_iNat7[df_iNat7['AVIBASEID']== 'BC5A9498']
# Out:
#        taxonID   taxonKey countryCode stateProvince  decimalLatitude  \
# 445     145245  7341805.0          US    California        37.809562
# 505     145245  7341805.0          US    California        39.036972
# 566     145245  7341805.0          US    California        37.277594
# 680     145245  7341805.0          US    California        38.350544
# 938     145245  7341805.0          US    California        37.502002
# ...        ...        ...         ...           ...              ...
# 362274  145245  7341805.0          US    California        36.982214
# 362345  145245  7341805.0          US    California        37.699575
# 362940  145245  7341805.0          US    California        37.535217
# 363208  145245  7341805.0          US    California        38.666373
# 363215  145245  7341805.0          US    California        37.318507
#
#         decimalLongitude            eventDate  \
# 445          -122.459509  2019-11-06T11:29:00
# 505          -121.730433  2019-04-14T12:20:00
# 566          -122.224529  2019-12-15T12:11:00
# 680          -121.229350  2019-03-30T12:00:29
# 938          -122.497143  2019-10-11T08:09:00
# ...                  ...                  ...
# 362274       -122.055677  2019-01-25T15:55:00
# 362345       -122.498096  2019-11-09T16:27:00
# 362940       -121.830360  2019-02-22T12:53:00
# 363208       -121.717618  2019-01-27T11:48:00
# 363215       -122.019280  2019-03-09T16:29:00
#
#                      acceptedScientificName  \
# 445     Setophaga coronata (Linnaeus, 1766)
# 505     Setophaga coronata (Linnaeus, 1766)
# 566     Setophaga coronata (Linnaeus, 1766)
# 680     Setophaga coronata (Linnaeus, 1766)
# 938     Setophaga coronata (Linnaeus, 1766)
# ...                                     ...
# 362274  Setophaga coronata (Linnaeus, 1766)
# 362345  Setophaga coronata (Linnaeus, 1766)
# 362940  Setophaga coronata (Linnaeus, 1766)
# 363208  Setophaga coronata (Linnaeus, 1766)
# 363215  Setophaga coronata (Linnaeus, 1766)
#
#                              scientificName      observation_dt  YEAR  WEEK  \
# 445     Setophaga coronata (Linnaeus, 1766) 2019-11-06 11:29:00  2019    45
# 505     Setophaga coronata (Linnaeus, 1766) 2019-04-14 12:20:00  2019    15
# 566     Setophaga coronata (Linnaeus, 1766) 2019-12-15 12:11:00  2019    50
# 680     Setophaga coronata (Linnaeus, 1766) 2019-03-30 12:00:29  2019    13
# 938     Setophaga coronata (Linnaeus, 1766) 2019-10-11 08:09:00  2019    41
# ...                                     ...                 ...   ...   ...
# 362274  Setophaga coronata (Linnaeus, 1766) 2019-01-25 15:55:00  2019     4
# 362345  Setophaga coronata (Linnaeus, 1766) 2019-11-09 16:27:00  2019    45
# 362940  Setophaga coronata (Linnaeus, 1766) 2019-02-22 12:53:00  2019     8
# 363208  Setophaga coronata (Linnaeus, 1766) 2019-01-27 11:48:00  2019     4
# 363215  Setophaga coronata (Linnaeus, 1766) 2019-03-09 16:29:00  2019    10
#
#                                             item iNat_Tid  ITIS_TSN  \
# 445     http://www.wikidata.org/entity/Q18390024   145245  950046.0
# 505     http://www.wikidata.org/entity/Q18390024   145245  950046.0
# 566     http://www.wikidata.org/entity/Q18390024   145245  950046.0
# 680     http://www.wikidata.org/entity/Q18390024   145245  950046.0
# 938     http://www.wikidata.org/entity/Q18390024   145245  950046.0
# ...                                          ...      ...       ...
# 362274  http://www.wikidata.org/entity/Q18390024   145245  950046.0
# 362345  http://www.wikidata.org/entity/Q18390024   145245  950046.0
# 362940  http://www.wikidata.org/entity/Q18390024   145245  950046.0
# 363208  http://www.wikidata.org/entity/Q18390024   145245  950046.0
# 363215  http://www.wikidata.org/entity/Q18390024   145245  950046.0
#
#            GBF_ID         avibaseid  iNat_Tid_num AVIBASEID
# 445     7341805.0  BC5A949807108302      145245.0  BC5A9498
# 505     7341805.0  BC5A949807108302      145245.0  BC5A9498
# 566     7341805.0  BC5A949807108302      145245.0  BC5A9498
# 680     7341805.0  BC5A949807108302      145245.0  BC5A9498
# 938     7341805.0  BC5A949807108302      145245.0  BC5A9498
# ...           ...               ...           ...       ...
# 362274  7341805.0  BC5A949807108302      145245.0  BC5A9498
# 362345  7341805.0  BC5A949807108302      145245.0  BC5A9498
# 362940  7341805.0  BC5A949807108302      145245.0  BC5A9498
# 363208  7341805.0  BC5A949807108302      145245.0  BC5A9498
# 363215  7341805.0  BC5A949807108302      145245.0  BC5A9498
#
# [834 rows x 19 columns]

# %% [markdown]
# # Adding Bird Name

# %%
name_birds = df_eBird[['TAXON CONCEPT ID', 'COMMON NAME']]

# %%
name_birds2 = name_birds.drop_duplicates().copy()

# %%
name_birds2.shape
# Out:
# (1088, 2)

# %%
name_birds2['AVIBASEID'] = name_birds2['TAXON CONCEPT ID'].apply(lambda x: x[-8:])

# %%
name_birds2
# Out:
#          TAXON CONCEPT ID                                  COMMON NAME  \
# 0        avibase-CA08045E                                Accipiter sp.
# 6        avibase-7E327303                             Acorn Woodpecker
# 193      avibase-C25794D5                          Allen's Hummingbird
# 199      avibase-8EB0C1FA                              American Avocet
# 517      avibase-13E9F9B4                             American Bittern
# ...                   ...                                          ...
# 8283270  avibase-977986EC  Red-crowned x Lilac-crowned Parrot (hybrid)
# 8309685  avibase-F89FD6E3                                  Little Gull
# 8320087  avibase-CA678E73         Gadwall x Green-winged Teal (hybrid)
# 8456596  avibase-4755009E                                Red Crossbill
# 8546745  avibase-64C6F7F0           American Wigeon x Mallard (hybrid)
#
#         AVIBASEID
# 0        CA08045E
# 6        7E327303
# 193      C25794D5
# 199      8EB0C1FA
# 517      13E9F9B4
# ...           ...
# 8283270  977986EC
# 8309685  F89FD6E3
# 8320087  CA678E73
# 8456596  4755009E
# 8546745  64C6F7F0
#
# [1088 rows x 3 columns]

# %%
df_eBird5 = df_eBird4.merge(name_birds2, how='left', on='AVIBASEID')

# %%
df_eBird5.shape
# Out:
# (3842332, 15)

# %%
df_eBird4.shape
# Out:
# (3842332, 13)

# %%
df_iNat7.shape
# Out:
# (71565, 19)

# %%
df_iNat8 = df_iNat7.merge(name_birds2, how='left', on='AVIBASEID')

# %%
df_iNat8
# Out:
#       taxonID   taxonKey countryCode stateProvince  decimalLatitude  \
# 0        6317  2476674.0          US    California        37.951323
# 1       18209  2478133.0          US    California        37.514882
# 2        4235  2482033.0          US    California        37.973925
# 3        6930  9761484.0          US    California        37.769881
# 4        4956  9630752.0          US    California        38.514781
# ...       ...        ...         ...           ...              ...
# 71560    4956  9630752.0          US    California        37.794537
# 71561    9100  2492196.0          US    California        38.552241
# 71562    9185  5231138.0          US    California        37.433635
# 71563  485176  2498155.0          US    California        37.582335
# 71564  508048  9036008.0          US    California        38.157721
#
#        decimalLongitude            eventDate  \
# 0           -122.598442  2019-05-08T07:49:00
# 1           -121.831151  2019-01-19T16:51:00
# 2           -121.827973  2019-03-14T11:26:00
# 3           -122.502033  2019-07-09T19:32:00
# 4           -121.616883  2019-09-11T07:09:00
# ...                 ...                  ...
# 71560       -122.466049  2019-06-07T08:18:57
# 71561       -121.629993  2019-09-14T09:59:00
# 71562       -122.097624  2019-01-10T13:54:00
# 71563       -122.314627  2019-02-09T07:46:00
# 71564       -121.443274  2019-12-16T16:59:00
#
#                            acceptedScientificName  \
# 0                   Calypte anna (R.Lesson, 1829)
# 1        Melanerpes formicivorus (Swainson, 1827)
# 2      Aechmophorus occidentalis (Lawrence, 1858)
# 3               Anas platyrhynchos Linnaeus, 1758
# 4                   Ardea herodias Linnaeus, 1758
# ...                                           ...
# 71560               Ardea herodias Linnaeus, 1758
# 71561          Melospiza melodia (A.Wilson, 1810)
# 71562  Zonotrichia atricapilla (J.F.Gmelin, 1789)
# 71563                 Anas americana Gmelin, 1789
# 71564            Grus canadensis (Linnaeus, 1758)
#
#                                    scientificName      observation_dt  ...  \
# 0                   Calypte anna (R.Lesson, 1829) 2019-05-08 07:49:00  ...
# 1        Melanerpes formicivorus (Swainson, 1827) 2019-01-19 16:51:00  ...
# 2      Aechmophorus occidentalis (Lawrence, 1858) 2019-03-14 11:26:00  ...
# 3               Anas platyrhynchos Linnaeus, 1758 2019-07-09 19:32:00  ...
# 4                   Ardea herodias Linnaeus, 1758 2019-09-11 07:09:00  ...
# ...                                           ...                 ...  ...
# 71560               Ardea herodias Linnaeus, 1758 2019-06-07 08:18:57  ...
# 71561          Melospiza melodia (A.Wilson, 1810) 2019-09-14 09:59:00  ...
# 71562  Zonotrichia atricapilla (J.F.Gmelin, 1789) 2019-01-10 13:54:00  ...
# 71563             Mareca americana (Gmelin, 1789) 2019-02-09 07:46:00  ...
# 71564        Antigone canadensis (Linnaeus, 1758) 2019-12-16 16:59:00  ...
#
#        WEEK                                      item iNat_Tid  ITIS_TSN  \
# 0        19    http://www.wikidata.org/entity/Q564265     6317  178036.0
# 1         3    http://www.wikidata.org/entity/Q368657    18209  178189.0
# 2        11    http://www.wikidata.org/entity/Q679154     4235  174503.0
# 3        28     http://www.wikidata.org/entity/Q25348     6930  175063.0
# 4        37    http://www.wikidata.org/entity/Q333796     4956  174773.0
# ...     ...                                       ...      ...       ...
# 71560    23    http://www.wikidata.org/entity/Q333796     4956  174773.0
# 71561    37    http://www.wikidata.org/entity/Q842599     9100  179492.0
# 71562     2    http://www.wikidata.org/entity/Q690956     9185  179461.0
# 71563     6  http://www.wikidata.org/entity/Q28106685   485176  175095.0
# 71564    51  http://www.wikidata.org/entity/Q28114133   508048       NaN
#
#           GBF_ID         avibaseid iNat_Tid_num  AVIBASEID  TAXON CONCEPT ID  \
# 0      2476674.0  423937213450C257       6317.0   42393721  avibase-42393721
# 1      2478133.0  7E3273031F76242B      18209.0   7E327303  avibase-7E327303
# 2      2482033.0  C6E1197BE78E2E17       4235.0   C6E1197B  avibase-C6E1197B
# 3      2498132.0  85625D75F2524457       6930.0   85625D75  avibase-85625D75
# 4      9630752.0  93694BB5492F7012       4956.0   93694BB5  avibase-93694BB5
# ...          ...               ...          ...        ...               ...
# 71560  9630752.0  93694BB5492F7012       4956.0   93694BB5  avibase-93694BB5
# 71561  2492196.0  A5F09E0521019564       9100.0   A5F09E05  avibase-A5F09E05
# 71562  5231138.0  BD61BDEC7D0A1633       9185.0   BD61BDEC  avibase-BD61BDEC
# 71563  2498155.0  D201EB7230F20770     485176.0   D201EB72  avibase-D201EB72
# 71564  9036008.0  E196D6F9AB1DFF7E     508048.0   E196D6F9  avibase-E196D6F9
#
#                   COMMON NAME
# 0          Anna's Hummingbird
# 1            Acorn Woodpecker
# 2               Western Grebe
# 3                     Mallard
# 4            Great Blue Heron
# ...                       ...
# 71560        Great Blue Heron
# 71561            Song Sparrow
# 71562  Golden-crowned Sparrow
# 71563         American Wigeon
# 71564          Sandhill Crane
#
# [71565 rows x 21 columns]

# %%
df_eBird5['AVIBASEID'].nunique()
# Out:
# 353

# %%
df_iNat8['AVIBASEID'].nunique()
# Out:
# 353

# %%
eBird_avibaseid_counts = df_eBird5.groupby(['AVIBASEID']).count()['STATE'].to_dict()

# %%
iNat_avibaseid_counts = df_iNat8.groupby("AVIBASEID").count()['stateProvince'].to_dict()

# %%
eBird_weekly_counts = df_eBird5.groupby(['AVIBASEID', 'COMMON NAME', 'WEEK']).count().reset_index()

# %%
eBird_weekly_counts2 = eBird_weekly_counts[['AVIBASEID', 'COMMON NAME', 'WEEK', 'COUNTRY']].copy()

# %%
eBird_weekly_counts2
# Out:
#       AVIBASEID             COMMON NAME  WEEK  COUNTRY
# 0      000482C9          Orchard Oriole     1       50
# 1      000482C9          Orchard Oriole     2       17
# 2      000482C9          Orchard Oriole     3        8
# 3      000482C9          Orchard Oriole     4        6
# 4      000482C9          Orchard Oriole     5       11
# ...         ...                     ...   ...      ...
# 13675  FFF61080  Orange-crowned Warbler    48      135
# 13676  FFF61080  Orange-crowned Warbler    49      141
# 13677  FFF61080  Orange-crowned Warbler    50      227
# 13678  FFF61080  Orange-crowned Warbler    51      183
# 13679  FFF61080  Orange-crowned Warbler    52      228
#
# [13680 rows x 4 columns]

# %%
eBird_weekly_counts2.columns = [
    'AVIBASEID', 'COMMON NAME', 'WEEK', 'COUNTS'
]

# %%
eBird_weekly_counts2
# Out:
#       AVIBASEID             COMMON NAME  WEEK  COUNTS
# 0      000482C9          Orchard Oriole     1      50
# 1      000482C9          Orchard Oriole     2      17
# 2      000482C9          Orchard Oriole     3       8
# 3      000482C9          Orchard Oriole     4       6
# 4      000482C9          Orchard Oriole     5      11
# ...         ...                     ...   ...     ...
# 13675  FFF61080  Orange-crowned Warbler    48     135
# 13676  FFF61080  Orange-crowned Warbler    49     141
# 13677  FFF61080  Orange-crowned Warbler    50     227
# 13678  FFF61080  Orange-crowned Warbler    51     183
# 13679  FFF61080  Orange-crowned Warbler    52     228
#
# [13680 rows x 4 columns]

# %%
eBird_weekly_counts2['REL_COUNTS'] = eBird_weekly_counts2.apply(
    lambda row: row['COUNTS']/ eBird_avibaseid_counts[row['AVIBASEID']],
    axis=1
).copy()

# %%
eBird_weekly_counts2['REL_COUNTS'].sum()
# Out:
# 353.0

# %%
iNat_weekly_counts = df_iNat8.groupby(['AVIBASEID', 'COMMON NAME', 'WEEK']).count().reset_index()

# %%
iNat_weekly_counts2 = iNat_weekly_counts[['AVIBASEID', 'COMMON NAME', 'WEEK', 'countryCode']].copy()

# %%
iNat_weekly_counts2
# Out:
#      AVIBASEID             COMMON NAME  WEEK  countryCode
# 0     000482C9          Orchard Oriole     1            1
# 1     000482C9          Orchard Oriole     2            2
# 2     000482C9          Orchard Oriole     9            1
# 3     000482C9          Orchard Oriole    38            1
# 4     000482C9          Orchard Oriole    40            2
# ...        ...                     ...   ...          ...
# 8848  FFF61080  Orange-crowned Warbler    48            1
# 8849  FFF61080  Orange-crowned Warbler    49            2
# 8850  FFF61080  Orange-crowned Warbler    50            4
# 8851  FFF61080  Orange-crowned Warbler    51            1
# 8852  FFF61080  Orange-crowned Warbler    52            4
#
# [8853 rows x 4 columns]

# %%
iNat_weekly_counts2.columns = [
    'AVIBASEID', 'COMMON NAME', 'WEEK', 'COUNTS'
]

# %%
iNat_weekly_counts2
# Out:
#      AVIBASEID             COMMON NAME  WEEK  COUNTS
# 0     000482C9          Orchard Oriole     1       1
# 1     000482C9          Orchard Oriole     2       2
# 2     000482C9          Orchard Oriole     9       1
# 3     000482C9          Orchard Oriole    38       1
# 4     000482C9          Orchard Oriole    40       2
# ...        ...                     ...   ...     ...
# 8848  FFF61080  Orange-crowned Warbler    48       1
# 8849  FFF61080  Orange-crowned Warbler    49       2
# 8850  FFF61080  Orange-crowned Warbler    50       4
# 8851  FFF61080  Orange-crowned Warbler    51       1
# 8852  FFF61080  Orange-crowned Warbler    52       4
#
# [8853 rows x 4 columns]

# %%
iNat_weekly_counts2['REL_COUNTS'] = iNat_weekly_counts2.apply(
    lambda row: row['COUNTS']/ iNat_avibaseid_counts[row['AVIBASEID']],
    axis=1
).copy()

# %%
iNat_weekly_counts2['REL_COUNTS'].sum()
# Out:
# 352.99999999999994

# %%
iNat_weekly_counts2
# Out:
#      AVIBASEID             COMMON NAME  WEEK  COUNTS  REL_COUNTS
# 0     000482C9          Orchard Oriole     1       1    0.125000
# 1     000482C9          Orchard Oriole     2       2    0.250000
# 2     000482C9          Orchard Oriole     9       1    0.125000
# 3     000482C9          Orchard Oriole    38       1    0.125000
# 4     000482C9          Orchard Oriole    40       2    0.250000
# ...        ...                     ...   ...     ...         ...
# 8848  FFF61080  Orange-crowned Warbler    48       1    0.005236
# 8849  FFF61080  Orange-crowned Warbler    49       2    0.010471
# 8850  FFF61080  Orange-crowned Warbler    50       4    0.020942
# 8851  FFF61080  Orange-crowned Warbler    51       1    0.005236
# 8852  FFF61080  Orange-crowned Warbler    52       4    0.020942
#
# [8853 rows x 5 columns]

# %%
name_avID_dict = iNat_weekly_counts2.iloc[:, 0:2].drop_duplicates().copy().set_index('AVIBASEID')['COMMON NAME'].to_dict()

# %%
name_avID_dict
# Out:
# {'000482C9': 'Orchard Oriole',
#  '00124D98': 'Mourning Dove',
#  '00635FF9': 'Pileated Woodpecker',
#  '01060BFD': 'Western Sandpiper',
#  '018B3169': 'Horned Grebe',
#  '029491CD': 'Gray-crowned Rosy-Finch',
#  '031409C7': 'Tricolored Heron',
#  '0337440E': "Bonaparte's Gull",
#  '03AC32BA': 'Glaucous-winged Gull',
#  '0413ED30': 'Black Turnstone',
#  '043F337A': 'Indigo Bunting',
#  '049D9AEA': 'Northern Fulmar',
#  '06B9BD24': 'Sanderling',
#  '0716A71C': 'Red-breasted Nuthatch',
#  '0783A7EA': 'Ring-necked Duck',
#  '07C11CF3': 'Pacific Golden-Plover',
#  '08F22F84': 'Flesh-footed Shearwater',
#  '0A4609D1': 'Red-footed Booby',
#  '0ADA5F17': 'Western Tanager',
#  '0B1B2EB6': 'Fox Sparrow',
#  '0BCBA6B9': 'Tundra Swan',
#  '0BDB87DE': 'Painted Bunting',
#  '0C120038': 'Yellow-browed Warbler',
#  '0D88C072': 'Spotted Sandpiper',
#  '0E599E6C': 'Cinnamon Teal',
#  '0EB07C12': 'Hermit Warbler',
#  '1044B438': 'Helmeted Guineafowl',
#  '11512CF4': 'Little Blue Heron',
#  '115AF02D': 'Black Tern',
#  '115F04DD': 'Green-winged Teal',
#  '11CF8C9A': 'Surfbird',
#  '12D5BA6C': 'Iceland Gull',
#  '12E354E2': 'Red-masked Parakeet',
#  '135564AA': 'Red Crossbill',
#  '13854B6E': 'Wandering Tattler',
#  '13E9F9B4': 'American Bittern',
#  '1456993D': 'Vermilion Flycatcher',
#  '145F1116': "Costa's Hummingbird",
#  '151C2B3F': 'California Scrub-Jay',
#  '15369E8E': 'Dunlin',
#  '154BCCAE': 'Golden-crowned Kinglet',
#  '15EE0D36': 'Eurasian Wigeon',
#  '171E91FF': 'Mountain Quail',
#  '1725B07D': 'Sooty Shearwater',
#  '178B8955': "Cassin's Kingbird",
#  '18A19380': 'Red Phalarope',
#  '1929E1E1': 'Canvasback',
#  '19CCBBD2': 'White-breasted Nuthatch',
#  '1BB9C864': 'Plumbeous Vireo',
#  '1CBD2CED': 'Red-necked Grebe',
#  '1DA430B8': 'Blue Jay',
#  '1E1AB415': 'Brown-headed Cowbird',
#  '1E1B6D19': 'Rufous Hummingbird',
#  '1E82CE1E': 'Magnolia Warbler',
#  '1EB2595E': "Hammond's Flycatcher",
#  '1F09CCCC': "Wilson's Warbler",
#  '1F1AD154': "Baird's Sandpiper",
#  '1F9D883E': 'Ruddy Shelduck',
#  '1FFFEF4E': 'Mountain Plover',
#  '20748450': 'California Thrasher',
#  '20C2214E': 'American Kestrel',
#  '2225D685': "Steller's Jay",
#  '2281F1C7': 'Western Kingbird',
#  '23863F65': 'Ring-billed Gull',
#  '240E3390': 'House Sparrow',
#  '249AE8DF': 'Marbled Godwit',
#  '24E39ACD': 'Common Nighthawk',
#  '24F14328': 'California Condor',
#  '25C94A8F': 'Greater Scaup',
#  '26BA25EF': 'Northern Saw-whet Owl',
#  '27903EF7': 'Black-bellied Plover',
#  '27B2749A': 'Wood Duck',
#  '28669A3D': "Say's Phoebe",
#  '28A4DA76': "Williamson's Sapsucker",
#  '295C4CD6': 'Worm-eating Warbler',
#  '2B46719D': 'Parakeet Auklet',
#  '2C7A2673': 'Lesser Yellowlegs',
#  '2CC21529': 'Sora',
#  '2CF6D6F6': "Cassin's Auklet",
#  '2DABF98F': 'Ruff',
#  '2F5DF476': 'Pigeon Guillemot',
#  '2FA39DCD': 'Ring-necked Pheasant',
#  '3072CC16': 'Redhead',
#  '31557374': 'Marbled Murrelet',
#  '319D044A': 'Red-throated Pipit',
#  '31ACA998': 'Band-tailed Pigeon',
#  '31CE00C7': 'Savannah Sparrow',
#  '32DCEC14': 'Eared Grebe',
#  '3558066B': 'Belted Kingfisher',
#  '36171C2B': 'Loggerhead Shrike',
#  '3647E146': 'Vesper Sparrow',
#  '36B3872D': 'Turkey Vulture',
#  '37E9CCDA': 'Chipping Sparrow',
#  '39086887': 'Parasitic Jaeger',
#  '39BD9FF2': 'White-throated Sparrow',
#  '39F29B55': 'Common Murre',
#  '3A3C62BC': 'Buff-breasted Sandpiper',
#  '3AC46C54': 'Double-crested Cormorant',
#  '3E04020B': 'Brant',
#  '3E2D0C9B': 'Yellow-headed Blackbird',
#  '3EF081A8': 'Common Gallinule',
#  '3F9E1C51': 'Elegant Tern',
#  '407E2CA8': 'Common Merganser',
#  '41062654': 'Northern Parula',
#  '4168AF09': 'Blackburnian Warbler',
#  '4185F617': "Ridgway's Rail",
#  '420850D6': 'Northern Goshawk',
#  '42393721': "Anna's Hummingbird",
#  '45D829B3': 'Green-tailed Towhee',
#  '466E9077': 'Greater White-fronted Goose',
#  '46B54DB1': 'Black Swan',
#  '486265CF': 'Clay-colored Sparrow',
#  '49D9148A': 'Great Egret',
#  '4A3B2CFF': 'Short-billed Dowitcher',
#  '4A5B4883': 'Western Meadowlark',
#  '4AAEF549': 'Palm Warbler',
#  '4AED44E8': 'Graylag Goose',
#  '4BB4F257': 'Black-chinned Hummingbird',
#  '4D207AF6': 'Black-and-white Warbler',
#  '4D2FF6F1': 'Common Tern',
#  '4E192262': 'Swamp Sparrow',
#  '4F28673C': 'Chilean Flamingo',
#  '4FF7DE80': 'Black Vulture',
#  '50566E50': 'Lesser Scaup',
#  '526A3692': 'Hooded Oriole',
#  '5284C27B': 'Long-billed Curlew',
#  '52F63879': 'Red-breasted Sapsucker',
#  '534FB490': 'Northern Gannet',
#  '536A5157': 'Red-tailed Hawk',
#  '538A9CA7': 'Yellow-billed Magpie',
#  '53D94597': 'Rhinoceros Auklet',
#  '544A5E6B': 'Blackpoll Warbler',
#  '5459228D': "Townsend's Solitaire",
#  '56036504': 'Neotropic Cormorant',
#  '56CCA717': 'Northern Pintail',
#  '575A3E3B': 'Western Gull',
#  '5816834E': 'Calliope Hummingbird',
#  '58312873': 'Varied Thrush',
#  '58C502EA': 'Barn Swallow',
#  '5BC4E0EF': 'Willow Flycatcher',
#  '5BFFE091': 'Grasshopper Sparrow',
#  '5CBA3391': 'Great-tailed Grackle',
#  '5EC21767': 'Brown Booby',
#  '5F8E7CA8': 'Golden Eagle',
#  '60214D49': 'Cackling Goose',
#  '603194D3': "Bewick's Wren",
#  '60E6081E': 'Hooded Merganser',
#  '624078BA': 'Surf Scoter',
#  '62CA2AF8': 'Eastern Phoebe',
#  '640D71AA': 'Black-billed Magpie',
#  '649F85B5': 'Blue-footed Booby',
#  '667C6969': "Wilson's Phalarope",
#  '67CEA1C1': 'Tufted Duck',
#  '68EA281A': 'Common Goldeneye',
#  '694C127A': 'Mute Swan',
#  '6996D540': "Heermann's Gull",
#  '6A7F76A7': 'Yellow-green Vireo',
#  '6B7A93C5': 'Black-throated Gray Warbler',
#  '6BB94D7E': 'Black-crowned Night-Heron',
#  '6BDADC9C': 'Black-backed Woodpecker',
#  '6C50988A': 'Red-throated Loon',
#  '6C74415D': 'White-headed Woodpecker',
#  '6CDC3C9C': 'Laughing Gull',
#  '6D2B5CDA': 'Ruffed Grouse',
#  '6D4F72B1': 'Scaly-breasted Munia',
#  '6EB81C98': 'Greater Yellowlegs',
#  '709AF716': 'Northern Waterthrush',
#  '734C73A9': 'Yellow-breasted Chat',
#  '75600969': 'Northern Flicker',
#  '75DC49AD': 'Violet-green Swallow',
#  '76DF73A9': 'Rock Wren',
#  '77567086': 'Selasphorus sp.',
#  '7784B060': 'Rufous-crowned Sparrow',
#  '78509A5D': 'Lark Sparrow',
#  '787E0536': 'Marsh Wren',
#  '79F3C681': 'Broad-winged Hawk',
#  '7A24F57F': "Ross's Goose",
#  '7AB1229B': 'Chestnut-sided Warbler',
#  '7B0669CB': 'Yellow-bellied Flycatcher',
#  '7CB8F5B7': 'Pomarine Jaeger',
#  '7E022378': 'Common Loon',
#  '7E327303': 'Acorn Woodpecker',
#  '7E65A952': "Bullock's Oriole",
#  '7EFF698D': 'Northern Mockingbird',
#  '7FCE8A43': 'California Gull',
#  '80285D5C': 'Tricolored Blackbird',
#  '824361E5': 'Black-headed Grosbeak',
#  '83F9C058': "Buller's Shearwater",
#  '85106518': "MacGillivray's Warbler",
#  '85625D75': 'Mallard',
#  '8601A467': 'White-crowned Sparrow',
#  '86182656': "Sabine's Gull",
#  '866903B9': 'American White Pelican',
#  '86D45B8F': 'Green Heron',
#  '87705CC4': 'Virginia Rail',
#  '87878948': "Bell's Sparrow",
#  '87CBEBF7': 'Chukar',
#  '88AB027C': 'Black Skimmer',
#  '891798D9': 'Summer Tanager',
#  '89431E9F': 'House Finch',
#  '89F8B6F5': 'Western Screech-Owl',
#  '8C4CE60F': 'Black-tailed Gull',
#  '8D6D5F2B': 'Great Crested Flycatcher',
#  '8DB64266': 'Red-breasted Merganser',
#  '8EB0C1FA': 'American Avocet',
#  '8F123A11': 'Short-eared Owl',
#  '8F268682': 'American Pipit',
#  '90B13ACF': 'Rough-legged Hawk',
#  '90E2543E': 'Blue-winged Teal',
#  '93013964': 'Hudsonian Godwit',
#  '930E8874': "Ridgway's Rail",
#  '93694BB5': 'Great Blue Heron',
#  '938C5572': 'Lark Bunting',
#  '9437D635': 'Cedar Waxwing',
#  '9456DEDF': "Barrow's Goldeneye",
#  '94A44032': 'European Starling',
#  '951C150C': 'Olive-sided Flycatcher',
#  '95B77F08': 'Gray Catbird',
#  '95E28A57': 'Semipalmated Plover',
#  '9690689D': 'Lesser Nighthawk',
#  '97B870B4': 'Mountain Bluebird',
#  '989B57D8': 'Wrentit',
#  '98FB6D4B': 'Laysan Albatross',
#  '9A684C99': 'Bar-tailed Godwit',
#  '9A77D2B0': 'Pink-footed Shearwater',
#  '9A8E55D0': 'Pied-billed Grebe',
#  '9BE68BD3': 'Yellow-bellied Sapsucker',
#  '9BEBC025': 'Snow Bunting',
#  '9BEECB7E': 'American Coot',
#  '9C5ED06A': 'Wild Turkey',
#  '9DBB70D5': 'Sulphur-bellied Flycatcher',
#  '9F67F3AF': 'Lazuli Bunting',
#  '9FFEDE99': 'Black-throated Green Warbler',
#  'A091D50A': 'Northern Harrier',
#  'A0F29F1E': 'Black-throated Sparrow',
#  'A15C5071': 'Blue-gray Gnatcatcher',
#  'A1F323F5': 'Empidonax sp.',
#  'A2BB98A9': 'Common Redpoll',
#  'A47B0BD4': 'Least Sandpiper',
#  'A59FA446': 'Glaucous Gull',
#  'A5EC8BF5': 'American Dipper',
#  'A5F09E05': 'Song Sparrow',
#  'A6905B3C': 'Pinyon Jay',
#  'A7A75EA1': 'Blue Grosbeak',
#  'A8C34DC9': 'Indian Peafowl',
#  'AA7901D8': 'Snowy Egret',
#  'AB1CB216': 'Cattle Egret',
#  'AC1E519F': "Cassin's Finch",
#  'AC2B812A': 'Western Bluebird',
#  'ACB9D1C6': 'Purple Martin',
#  'ACC99F35': 'Pectoral Sandpiper',
#  'AF0C7BDE': 'Long-tailed Duck',
#  'AF49F890': "Lincoln's Sparrow",
#  'B01E8BD4': 'Hermit Thrush',
#  'B12B8816': 'Pacific-slope/Cordilleran Flycatcher (Western Flycatcher)',
#  'B182DED2': 'Black Phoebe',
#  'B1F0CC82': 'Black-capped Chickadee',
#  'B401C2DD': 'White-throated Swift',
#  'B48335B1': 'Pine Siskin',
#  'B4EE123D': 'Purple Finch',
#  'B59E1863': 'Canada Goose',
#  'B5CE8FAD': 'Red Knot',
#  'B745D852': 'California Towhee',
#  'B77377EE': 'Common Eider',
#  'B7B1A5DD': 'Black Scoter',
#  'B7D7EF23': 'Pacific Loon',
#  'B7E467E2': 'Greater Sage-Grouse',
#  'B86C504C': 'Trumpeter Swan',
#  'B9B272F4': 'Common Raven',
#  'B9EE9676': 'Burrowing Owl',
#  'BA4C8A02': 'Common Yellowthroat',
#  'BA9191BC': 'Ferruginous Hawk',
#  'BAC33609': 'Brown Creeper',
#  'BB6B236F': 'Tropical Kingbird',
#  'BBA2F9DF': 'Tree Swallow',
#  'BBFF0963': 'Prairie Falcon',
#  'BC06BC0D': 'Caspian Tern',
#  'BC5A9498': 'Yellow-rumped Warbler',
#  'BCBD2EAE': 'Harlequin Duck',
#  'BCF9A19A': 'Killdeer',
#  'BD0914CB': 'Pygmy Nuthatch',
#  'BD49DB46': 'Black Oystercatcher',
#  'BD61BDEC': 'Golden-crowned Sparrow',
#  'BD929CBC': 'Phainopepla',
#  'BDBB04D5': 'Barred Owl',
#  'BDC5CF80': 'Arctic Tern',
#  'BE78E765': 'Least Tern',
#  'C235A4D7': 'Gadwall',
#  'C25794D5': "Allen's Hummingbird",
#  'C27D9E26': "Lawrence's Goldfinch",
#  'C3168495': "Bell's Vireo",
#  'C53F4940': 'White-tailed Ptarmigan',
#  'C5971E25': 'Rock Sandpiper',
#  'C6772490': 'Yellow-crowned Night-Heron',
#  'C6E1197B': 'Western Grebe',
#  'C9ABA616': 'American Goldfinch',
#  'CAA5E106': 'White-tailed Kite',
#  'CB343E43': 'Long-billed Dowitcher',
#  'CEA5B6AA': 'Ovenbird',
#  'D05FFEF7': "Clark's Grebe",
#  'D13B9122': "Forster's Tern",
#  'D201EB72': 'American Wigeon',
#  'D204A930': 'Tennessee Warbler',
#  'D3A260BC': 'Snow Goose',
#  'D4540F88': 'Glossy Ibis',
#  'D621FFC6': 'Common Poorwill',
#  'DA2F24E3': 'Egyptian Goose',
#  'DACF7A98': 'Gray Flycatcher',
#  'DB5DABCF': 'Greater Roadrunner',
#  'DC3050A9': 'Ruddy Turnstone',
#  'DDAF0666': "Harris's Sparrow",
#  'DE0971C1': 'Mountain Chickadee',
#  'DE473F42': "Swainson's Hawk",
#  'E0A04985': 'Ash-throated Flycatcher',
#  'E1714A09': 'Mandarin Duck',
#  'E196D6F9': 'Sandhill Crane',
#  'E36325FA': 'Prairie Warbler',
#  'E366AB90': 'Juniper Titmouse',
#  'E4A5B66A': 'Sooty Grouse',
#  'E53FC25C': "Swainson's Thrush",
#  'E6F3BA54': 'Red-necked Phalarope',
#  'E7A14E91': 'Willet',
#  'E7C9A1F5': "Lewis's Woodpecker",
#  'EA4D6C0B': 'Red-shouldered Hawk',
#  'EA5E858A': "Brewer's Blackbird",
#  'EAD14427': 'Canyon Wren',
#  'EB0CD5DC': "Cassin's Vireo",
#  'EB98812F': "Cooper's Hawk",
#  'ECDE73F2': 'Stilt Sandpiper',
#  'ED4CE8E7': 'Northern Shoveler',
#  'EE8ECB1D': 'Black-footed Albatross',
#  'F012ED4B': 'Snowy Plover',
#  'F35821AA': 'Semipalmated Sandpiper',
#  'F3DA111C': 'Merlin',
#  'F577BA0F': 'Garganey',
#  'F5837054': 'Least Flycatcher',
#  'F59AB6B3': 'Brown Pelican',
#  'F5C181CA': 'Cliff Swallow',
#  'F5C8516D': "Wilson's Snipe",
#  'F6C6C3F7': "Townsend's Warbler",
#  'F6CA75F0': 'Western Wood-Pewee',
#  'F6DF700B': 'Sage Thrasher',
#  'F7937349': 'Tufted Puffin',
#  'F8DDF6A6': 'Yellow-throated Vireo',
#  'F9305BAA': 'Whimbrel',
#  'F93AC929': 'California Quail',
#  'FB4D08F0': 'Black-legged Kittiwake',
#  'FB738385': 'Bufflehead',
#  'FC366114': 'Great Horned Owl',
#  'FD2B0309': 'White-faced Ibis',
#  'FED3756C': 'Bald Eagle',
#  'FF592882': 'Chestnut-backed Chickadee',
#  'FFF61080': 'Orange-crowned Warbler'}

# %%
eBird_curves_discrete = eBird_weekly_counts2.pivot_table(index='AVIBASEID', columns='WEEK', values='REL_COUNTS' )

# %%
eBird_curves_discrete.fillna(value=0, inplace=True)

# %%
iNat_curves_discrete = iNat_weekly_counts2.pivot_table(index='AVIBASEID', columns='WEEK', values='REL_COUNTS' )

# %%
iNat_curves_discrete.fillna(value=0, inplace=True)

# %%
eBird_curves_discrete
# Out:
# WEEK             1         2         3         4         5         6   \
# AVIBASEID
# 000482C9   0.119048  0.040476  0.019048  0.014286  0.026190  0.007143
# 00124D98   0.022217  0.017285  0.012884  0.018823  0.015717  0.016278
# 00635FF9   0.014224  0.007715  0.009643  0.014706  0.005304  0.006750
# 01060BFD   0.021075  0.017118  0.009295  0.021535  0.008927  0.015093
# 018B3169   0.062974  0.057585  0.037885  0.063984  0.046304  0.040411
# ...             ...       ...       ...       ...       ...       ...
# FC366114   0.041123  0.026198  0.021083  0.032773  0.021188  0.022231
# FD2B0309   0.027732  0.018818  0.016177  0.027567  0.008254  0.007098
# FED3756C   0.045327  0.034529  0.028118  0.050163  0.017321  0.025644
# FF592882   0.023050  0.018095  0.012938  0.018866  0.014223  0.014645
# FFF61080   0.013699  0.010236  0.005469  0.008480  0.006624  0.004867
#
# WEEK             7         8         9         10  ...        43        44  \
# AVIBASEID                                          ...
# 000482C9   0.014286  0.009524  0.009524  0.014286  ...  0.026190  0.033333
# 00124D98   0.016436  0.018622  0.015286  0.017831  ...  0.010181  0.012554
# 00635FF9   0.009161  0.015670  0.003857  0.007473  ...  0.013259  0.010849
# 01060BFD   0.011412  0.016934  0.008099  0.009111  ...  0.014817  0.019418
# 018B3169   0.040579  0.059269  0.036707  0.028456  ...  0.009092  0.027277
# ...             ...       ...       ...       ...  ...       ...       ...
# FC366114   0.020770  0.029746  0.019100  0.023797  ...  0.016282  0.015134
# FD2B0309   0.008749  0.018323  0.003136  0.013701  ...  0.013866  0.018983
# FED3756C   0.023394  0.028681  0.020020  0.016871  ...  0.013159  0.014059
# FF592882   0.015966  0.020885  0.014388  0.014388  ...  0.016884  0.020279
# FFF61080   0.004265  0.011441  0.006322  0.009132  ...  0.006975  0.008229
#
# WEEK             45        46        47        48        49        50  \
# AVIBASEID
# 000482C9   0.038095  0.040476  0.042857  0.021429  0.004762  0.021429
# 00124D98   0.012022  0.014452  0.013028  0.012022  0.012741  0.018349
# 00635FF9   0.017840  0.016876  0.013259  0.005786  0.005304  0.016152
# 01060BFD   0.022731  0.016013  0.017394  0.015553  0.014081  0.015829
# 018B3169   0.038727  0.031824  0.033002  0.034349  0.034012  0.049167
# ...             ...       ...       ...       ...       ...       ...
# FC366114   0.019309  0.020248  0.018474  0.010437  0.014925  0.034548
# FD2B0309   0.016507  0.022945  0.023440  0.016177  0.008088  0.008584
# FED3756C   0.014509  0.023282  0.035429  0.022720  0.016309  0.037454
# FF592882   0.019251  0.022114  0.017361  0.015452  0.013525  0.025968
# FFF61080   0.008530  0.008580  0.012344  0.006774  0.007075  0.011390
#
# WEEK             51        52
# AVIBASEID
# 000482C9   0.028571  0.042857
# 00124D98   0.015386  0.017026
# 00635FF9   0.007956  0.013259
# 01060BFD   0.009387  0.014265
# 018B3169   0.023741  0.041253
# ...             ...       ...
# FC366114   0.023484  0.020562
# FD2B0309   0.015517  0.014526
# FED3756C   0.027443  0.032167
# FF592882   0.014388  0.019967
# FFF61080   0.009183  0.011441
#
# [353 rows x 52 columns]

# %%
iNat_curves_discrete
# Out:
# WEEK             1         2         3         4         5         6   \
# AVIBASEID
# 000482C9   0.125000  0.250000  0.000000  0.000000  0.000000  0.000000
# 00124D98   0.011551  0.014851  0.004950  0.021452  0.013201  0.003300
# 00635FF9   0.010204  0.000000  0.010204  0.010204  0.020408  0.010204
# 01060BFD   0.019900  0.029851  0.000000  0.029851  0.000000  0.004975
# 018B3169   0.049587  0.049587  0.016529  0.074380  0.024793  0.024793
# ...             ...       ...       ...       ...       ...       ...
# FC366114   0.014205  0.008523  0.008523  0.036932  0.028409  0.017045
# FD2B0309   0.000000  0.025105  0.033473  0.033473  0.008368  0.012552
# FED3756C   0.021739  0.039855  0.014493  0.057971  0.021739  0.010870
# FF592882   0.012195  0.012195  0.006969  0.013937  0.010453  0.010453
# FFF61080   0.015707  0.010471  0.015707  0.005236  0.005236  0.026178
#
# WEEK             7         8         9         10  ...        43        44  \
# AVIBASEID                                          ...
# 000482C9   0.000000  0.000000  0.125000  0.000000  ...  0.125000  0.000000
# 00124D98   0.004950  0.013201  0.009901  0.014851  ...  0.011551  0.011551
# 00635FF9   0.020408  0.000000  0.000000  0.020408  ...  0.030612  0.020408
# 01060BFD   0.024876  0.014925  0.000000  0.004975  ...  0.004975  0.014925
# 018B3169   0.000000  0.057851  0.000000  0.033058  ...  0.008264  0.016529
# ...             ...       ...       ...       ...  ...       ...       ...
# FC366114   0.011364  0.019886  0.011364  0.022727  ...  0.008523  0.017045
# FD2B0309   0.000000  0.016736  0.000000  0.008368  ...  0.037657  0.016736
# FED3756C   0.039855  0.028986  0.010870  0.014493  ...  0.021739  0.003623
# FF592882   0.012195  0.026132  0.024390  0.013937  ...  0.019164  0.027875
# FFF61080   0.005236  0.015707  0.010471  0.015707  ...  0.005236  0.010471
#
# WEEK             45        46        47        48        49        50  \
# AVIBASEID
# 000482C9   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 00124D98   0.006601  0.019802  0.004950  0.014851  0.009901  0.008251
# 00635FF9   0.051020  0.010204  0.000000  0.030612  0.000000  0.020408
# 01060BFD   0.054726  0.004975  0.029851  0.014925  0.000000  0.019900
# 018B3169   0.049587  0.041322  0.008264  0.024793  0.016529  0.049587
# ...             ...       ...       ...       ...       ...       ...
# FC366114   0.008523  0.031250  0.017045  0.005682  0.005682  0.014205
# FD2B0309   0.004184  0.020921  0.016736  0.025105  0.004184  0.008368
# FED3756C   0.025362  0.025362  0.014493  0.010870  0.010870  0.025362
# FF592882   0.008711  0.012195  0.006969  0.012195  0.017422  0.020906
# FFF61080   0.010471  0.010471  0.005236  0.005236  0.010471  0.020942
#
# WEEK             51        52
# AVIBASEID
# 000482C9   0.000000  0.000000
# 00124D98   0.018152  0.006601
# 00635FF9   0.000000  0.010204
# 01060BFD   0.000000  0.009950
# 018B3169   0.057851  0.057851
# ...             ...       ...
# FC366114   0.019886  0.005682
# FD2B0309   0.029289  0.008368
# FED3756C   0.014493  0.043478
# FF592882   0.012195  0.015679
# FFF61080   0.005236  0.020942
#
# [353 rows x 52 columns]

# %%
import matplotlib.pyplot as plt

# %%
# %config inlineBackend.figure_format = 'retina'

# %%
def make_discrete_curves(x):
    aviID = x
    plt.plot(iNat_curves_discrete.loc[x, :], label='iNat_data')
    plt.plot(eBird_curves_discrete.loc[x, :], label='eBird_data')
    plt.legend()
    plt.title(f"Observation Curves for the bird: {name_avID_dict[x]}")

# %%
df_eBird5.groupby(['AVIBASEID']).count().sort_values(by='WEEK', ascending=False)
# Out:
#            TAXON CONCEPT ID_x  OBSERVATION COUNT  COUNTRY   STATE  LATITUDE  \
# AVIBASEID
# B182DED2               110466             110466   110466  110466    110466
# 42393721               105154             105154   105154  105154    105154
# 89431E9F                98275              98275    98275   98275     98275
# 151C2B3F                97752              97752    97752   97752     97752
# 36B3872D                93057              93057    93057   93057     93057
# ...                       ...                ...      ...     ...       ...
# 1044B438                    4                  4        4       4         4
# D4540F88                    4                  4        4       4         4
# 56036504                    3                  3        3       3         3
# A8C34DC9                    2                  2        2       2         2
# 4AED44E8                    1                  1        1       1         1
#
#            LONGITUDE  OBSERVATION DATE  SCIENTIFIC NAME  OBSCOUNT  \
# AVIBASEID
# B182DED2      110466            110466           110466    110466
# 42393721      105154            105154           105154    105154
# 89431E9F       98275             98275            98275     98275
# 151C2B3F       97752             97752            97752     97752
# 36B3872D       93057             93057            93057     93057
# ...              ...               ...              ...       ...
# 1044B438           4                 4                4         4
# D4540F88           4                 4                4         4
# 56036504           3                 3                3         3
# A8C34DC9           2                 2                2         2
# 4AED44E8           1                 1                1         1
#
#            observation_datetime    WEEK    YEAR  TAXON CONCEPT ID_y  \
# AVIBASEID
# B182DED2                 110466  110466  110466              110466
# 42393721                 105154  105154  105154              105154
# 89431E9F                  98275   98275   98275               98275
# 151C2B3F                  97752   97752   97752               97752
# 36B3872D                  93057   93057   93057               93057
# ...                         ...     ...     ...                 ...
# 1044B438                      4       4       4                   4
# D4540F88                      4       4       4                   4
# 56036504                      3       3       3                   3
# A8C34DC9                      2       2       2                   2
# 4AED44E8                      1       1       1                   1
#
#            COMMON NAME
# AVIBASEID
# B182DED2        110466
# 42393721        105154
# 89431E9F         98275
# 151C2B3F         97752
# 36B3872D         93057
# ...                ...
# 1044B438             4
# D4540F88             4
# 56036504             3
# A8C34DC9             2
# 4AED44E8             1
#
# [353 rows x 14 columns]

# %%
make_discrete_curves("89431E9F")

# %%
import scipy

# %%
iNat_curves_discrete.loc["89431E9F", :]
# Out:
# WEEK
# 1     0.010280
# 2     0.016822
# 3     0.010280
# 4     0.025234
# 5     0.004673
# 6     0.007477
# 7     0.012150
# 8     0.022430
# 9     0.009346
# 10    0.014019
# 11    0.016822
# 12    0.016822
# 13    0.016822
# 14    0.028037
# 15    0.023364
# 16    0.022430
# 17    0.068224
# 18    0.041121
# 19    0.022430
# 20    0.021495
# 21    0.026168
# 22    0.028972
# 23    0.016822
# 24    0.017757
# 25    0.015888
# 26    0.018692
# 27    0.019626
# 28    0.024299
# 29    0.026168
# 30    0.020561
# 31    0.013084
# 32    0.019626
# 33    0.014019
# 34    0.015888
# 35    0.036449
# 36    0.025234
# 37    0.011215
# 38    0.009346
# 39    0.018692
# 40    0.014019
# 41    0.014953
# 42    0.015888
# 43    0.012150
# 44    0.017757
# 45    0.014953
# 46    0.015888
# 47    0.024299
# 48    0.012150
# 49    0.017757
# 50    0.016822
# 51    0.014019
# 52    0.020561
# Name: 89431E9F, dtype: float64

# %%
scipy.ndimage.gaussian_filter(
    iNat_curves_discrete.loc["89431E9F", :],
    3
)
# Out:
# array([0.01339856, 0.0133622 , 0.01329956, 0.01324141, 0.01324553,
#        0.01338154, 0.01371456, 0.01429422, 0.01516504, 0.01638161,
#        0.01800673, 0.02007613, 0.02254135, 0.02521543, 0.02776413,
#        0.02977156, 0.03087072, 0.0308845 , 0.02989347, 0.0281971 ,
#        0.02619122, 0.02424242, 0.02261091, 0.02142949, 0.02071166,
#        0.02037047, 0.02025324, 0.02019879, 0.0201016 , 0.01994671,
#        0.01979022, 0.01968751, 0.0196262 , 0.01951099, 0.01921684,
#        0.01867351, 0.01792058, 0.01709304, 0.01635371, 0.0158239 ,
#        0.01555075, 0.01551683, 0.01566725, 0.01593159, 0.0162375 ,
#        0.01652389, 0.01675153, 0.01691156, 0.01701955, 0.01709617,
#        0.01715185, 0.01718317])

# %%
def function_smoothing(x, sigma=3):
    y = scipy.ndimage.gaussian_filter(
        x,
        sigma
    )
    return y

# %%
def make_smooth_curves(x, sigma=3):
    aviID = x
    y1_smoothed = function_smoothing(
        iNat_curves_discrete.loc[aviID, :],
        sigma=sigma
    )
    y2_smoothed = function_smoothing(
        eBird_curves_discrete.loc[aviID, :],
        sigma=sigma
    )
    plt.plot(y1_smoothed, label='iNat_data')
    plt.plot(y2_smoothed, label='eBird_data')
    plt.legend()
    plt.title(f"Observation Curves for the bird: {name_avID_dict[x]}")

# %%
make_smooth_curves("36B3872D", sigma=2)

# %%
make_discrete_curves("36B3872D")

# %%
y1 = iNat_curves_discrete.loc["89431E9F", :]

# %%
y1[15:20]
# Out:
# WEEK
# 16    0.022430
# 17    0.068224
# 18    0.041121
# 19    0.022430
# 20    0.021495
# Name: 89431E9F, dtype: float64

# %%
y1[16:18] = None

# %%
y1
# Out:
# WEEK
# 1     0.010280
# 2     0.016822
# 3     0.010280
# 4     0.025234
# 5     0.004673
# 6     0.007477
# 7     0.012150
# 8     0.022430
# 9     0.009346
# 10    0.014019
# 11    0.016822
# 12    0.016822
# 13    0.016822
# 14    0.028037
# 15    0.023364
# 16    0.022430
# 17         NaN
# 18         NaN
# 19    0.022430
# 20    0.021495
# 21    0.026168
# 22    0.028972
# 23    0.016822
# 24    0.017757
# 25    0.015888
# 26    0.018692
# 27    0.019626
# 28    0.024299
# 29    0.026168
# 30    0.020561
# 31    0.013084
# 32    0.019626
# 33    0.014019
# 34    0.015888
# 35    0.036449
# 36    0.025234
# 37    0.011215
# 38    0.009346
# 39    0.018692
# 40    0.014019
# 41    0.014953
# 42    0.015888
# 43    0.012150
# 44    0.017757
# 45    0.014953
# 46    0.015888
# 47    0.024299
# 48    0.012150
# 49    0.017757
# 50    0.016822
# 51    0.014019
# 52    0.020561
# Name: 89431E9F, dtype: float64

# %%
def make_smooth_curves_rm2wk_iNat(x, sigma=3):
    aviID = x
    y1 = iNat_curves_discrete.loc[aviID, :]
    y1[16:18] = None
    y1_smoothed = function_smoothing(
        y1,
        sigma=sigma
    )
    y2_smoothed = function_smoothing(
        eBird_curves_discrete.loc[aviID, :],
        sigma=sigma
    )
    plt.plot(y1_smoothed, label='iNat_data')
    plt.plot(y2_smoothed, label='eBird_data')
    plt.legend()
    plt.title(f"Observation Curves for the bird: {name_avID_dict[x]}")

# %%
make_smooth_curves_rm2wk_iNat("89431E9F", sigma=0.1)

# %% [markdown]
# # Plots

# %%
import seaborn as sns

# %% [markdown]
# df_ebird5, inat8

# %%
eda_inat1= df_iNat8.groupby('COMMON NAME').count()['taxonID']/716.02

# %%
eda_inat1.sort_values(ascending=False)
# Out:
# COMMON NAME
# Red-tailed Hawk               3.273652
# Anna's Hummingbird            2.698249
# Mallard                       2.553001
# White-crowned Sparrow         2.150778
# Great Egret                   2.147985
#                                 ...
# Sulphur-bellied Flycatcher    0.001397
# Prairie Warbler               0.001397
# Flesh-footed Shearwater       0.001397
# Eastern Phoebe                0.001397
# Yellow-throated Vireo         0.001397
# Name: taxonID, Length: 352, dtype: float64

# %%
eda_ebird = df_eBird5.groupby('COMMON NAME').count()['AVIBASEID']

# %%
eda_ebird = eda_ebird/38423.32

# %%
eda_ebird.sort_values(ascending=False)
# Out:
# COMMON NAME
# Black Phoebe            2.874973
# Anna's Hummingbird      2.736723
# House Finch             2.557692
# California Scrub-Jay    2.544080
# Turkey Vulture          2.421889
#                           ...
# Glossy Ibis             0.000104
# Helmeted Guineafowl     0.000104
# Neotropic Cormorant     0.000078
# Indian Peafowl          0.000052
# Graylag Goose           0.000026
# Name: AVIBASEID, Length: 352, dtype: float64

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(1,1,figsize=(8,4))
sns.kdeplot(eda_ebird.values, ax=ax, label='eBird', color='#142231', bw_adjust=0.2)
sns.kdeplot(eda_inat1.values, ax=ax, label='i-Naturalist', color='#FBA210', bw_adjust=0.2)
ax.legend()

# %%
eda_diff = eda_ebird.sort_index() - eda_inat1.sort_index()

# %%
eda_diff.describe()
# Out:
# count    3.520000e+02
# mean    -1.009294e-17
# std      2.587908e-01
# min     -1.470059e+00
# 25%     -3.255552e-02
# 50%     -1.088524e-03
# 75%      3.080370e-02
# max      1.195224e+00
# dtype: float64

# %%
import numpy as np

# %%
eda_diff_abs = np.abs(eda_diff)

# %%
eda_diff_abs.sort_values(ascending=False)
# Out:
# COMMON NAME
# Red-tailed Hawk             1.470059
# Wild Turkey                 1.396315
# Neotropic Cormorant         1.342063
# American Coot               1.272878
# European Starling           1.195224
#                               ...
# Rough-legged Hawk           0.000107
# Great Crested Flycatcher    0.000087
# Swamp Sparrow               0.000086
# Least Flycatcher            0.000069
# Blue Jay                    0.000009
# Length: 352, dtype: float64

# %%
eda_diff.sort_values()
# Out:
# COMMON NAME
# Red-tailed Hawk       -1.470059
# Wild Turkey           -1.396315
# Neotropic Cormorant   -1.342063
# American Coot         -1.272878
# Great Blue Heron      -1.020892
#                          ...
# Turkey Vulture         0.799029
# Mourning Dove          0.963545
# Common Raven           0.994793
# House Finch            1.060527
# European Starling      1.195224
# Length: 352, dtype: float64
