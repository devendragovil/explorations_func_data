# %%
from keplergl import KeplerGl
map_1 = KeplerGl()
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter

# %%
import pandas as pd

# %%
df_iNat_filtered = pd.read_csv('./df_iNat_filtered.csv')

# %%
df_iNat_filtered
# Out:
#          latitude   longitude  taxon_id quality_grade observed_on  \
# 0       37.954959 -122.577219   48267.0      research  2019-03-18
# 1       37.848045 -122.547270  777371.0      research  2019-04-29
# 2       41.427866 -120.546127    5200.0      research  2019-01-23
# 3       37.770409 -122.184913   68912.0      research  2019-01-01
# 4       37.294892 -122.091177     906.0      research  2019-01-01
# ...           ...         ...       ...           ...         ...
# 352643  38.736551 -122.000738   67781.0      research  2019-03-01
# 352644  38.638785 -122.169255   67781.0      research  2019-03-01
# 352645  38.601451 -122.106937   67781.0      research  2019-03-01
# 352646  38.675038 -119.589583   52542.0      research  2019-07-09
# 352647  41.209746 -122.517100   75440.0      research  2019-07-31
#
#        observed_on_dt  observed_on_year  observed_on_mon  observed_on_week
# 0          2019-03-18              2019                3                12
# 1          2019-04-29              2019                4                18
# 2          2019-01-23              2019                1                 4
# 3          2019-01-01              2019                1                 1
# 4          2019-01-01              2019                1                 1
# ...               ...               ...              ...               ...
# 352643     2019-03-01              2019                3                 9
# 352644     2019-03-01              2019                3                 9
# 352645     2019-03-01              2019                3                 9
# 352646     2019-07-09              2019                7                28
# 352647     2019-07-31              2019                7                31
#
# [352648 rows x 9 columns]

# %%
df_iNat_filtered.columns = ['Latitude', 'Longitude', 'taxon_id', 'quality_grade', 'observed_on',
       'observed_on_dt', 'observed_on_year', 'observed_on_mon',
       'observed_on_week']

# %%
df_iNat_filtered
# Out:
#          Latitude   Longitude  taxon_id quality_grade observed_on  \
# 0       37.954959 -122.577219   48267.0      research  2019-03-18
# 1       37.848045 -122.547270  777371.0      research  2019-04-29
# 2       41.427866 -120.546127    5200.0      research  2019-01-23
# 3       37.770409 -122.184913   68912.0      research  2019-01-01
# 4       37.294892 -122.091177     906.0      research  2019-01-01
# ...           ...         ...       ...           ...         ...
# 352643  38.736551 -122.000738   67781.0      research  2019-03-01
# 352644  38.638785 -122.169255   67781.0      research  2019-03-01
# 352645  38.601451 -122.106937   67781.0      research  2019-03-01
# 352646  38.675038 -119.589583   52542.0      research  2019-07-09
# 352647  41.209746 -122.517100   75440.0      research  2019-07-31
#
#        observed_on_dt  observed_on_year  observed_on_mon  observed_on_week
# 0          2019-03-18              2019                3                12
# 1          2019-04-29              2019                4                18
# 2          2019-01-23              2019                1                 4
# 3          2019-01-01              2019                1                 1
# 4          2019-01-01              2019                1                 1
# ...               ...               ...              ...               ...
# 352643     2019-03-01              2019                3                 9
# 352644     2019-03-01              2019                3                 9
# 352645     2019-03-01              2019                3                 9
# 352646     2019-07-09              2019                7                28
# 352647     2019-07-31              2019                7                31
#
# [352648 rows x 9 columns]

# %%
map_1.add_data(data=df_iNat_filtered[['Latitude', 'Longitude']].sample(n=200_000), name='iNat')

# %%
map_2 = KeplerGl()
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter

# %%
df_ebird_filtered = pd.read_csv('./df_ebird_filtered.csv')

# %%
df_ebird_filtered.shape
# Out:
# (5168169, 7)

# %%
df_ebird_filtered.columns = ['TAXON CONCEPT ID', 'COMMON NAME', 'SCIENTIFIC NAME',
       'OBSERVATION COUNT', 'Latitude', 'Longitude', 'OBSERVATION DATE']

# %%
map_2.add_data(data=df_ebird_filtered[['Latitude', 'Longitude']].sample(n=200_000), name='eBird')

# %%
df_boundingbox = pd.DataFrame(
    {
        "point": ["A", "B", "C", "D"],
        "starting_lat": [36.470113287, 42.009518, 42.009518, 36.470113287],
        "end_lat": [42.009518, 42.009518, 36.470113287, 36.470113287],
        "start_lon": [-124.409591, -124.409591, -114.131211, -114.131211],
        "ending_lon": [-124.409591, -114.131211, -114.131211, -124.409591]
    }
)

# %%
map_2.add_data(data=df_boundingbox, name="boundingbox")
map_1.add_data(data=df_boundingbox, name="boundingbox")

# %%
display(map_1)
# Out:
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [], 'interactionConfig': {'…

# %%
map_1.config
# Out:
# {'version': 'v1',
#  'config': {'visState': {'filters': [],
#    'layers': [{'id': '6tb43j',
#      'type': 'grid',
#      'config': {'dataId': 'iNat',
#       'label': 'Point',
#       'color': [130, 154, 227],
#       'highlightColor': [252, 242, 26, 255],
#       'columns': {'lat': 'Latitude', 'lng': 'Longitude'},
#       'isVisible': True,
#       'visConfig': {'opacity': 0.8,
#        'worldUnitSize': 2,
#        'colorRange': {'name': 'Global Warming',
#         'type': 'sequential',
#         'category': 'Uber',
#         'colors': ['#5A1846',
#          '#900C3F',
#          '#C70039',
#          '#E3611C',
#          '#F1920E',
#          '#FFC300']},
#        'coverage': 1,
#        'sizeRange': [0, 500],
#        'percentile': [0, 100],
#        'elevationPercentile': [0, 100],
#        'elevationScale': 5,
#        'enableElevationZoomFactor': True,
#        'colorAggregation': 'count',
#        'sizeAggregation': 'count',
#        'enable3d': False},
#       'hidden': False,
#       'textLabel': [{'field': None,
#         'color': [255, 255, 255],
#         'size': 18,
#         'offset': [0, 0],
#         'anchor': 'start',
#         'alignment': 'center'}]},
#      'visualChannels': {'colorField': None,
#       'colorScale': 'quantile',
#       'sizeField': None,
#       'sizeScale': 'linear'}},
#     {'id': 'il8svz',
#      'type': 'line',
#      'config': {'dataId': 'boundingbox',
#       'label': 'BoundingBox',
#       'color': [136, 87, 44],
#       'highlightColor': [252, 242, 26, 255],
#       'columns': {'lat0': 'starting_lat',
#        'lng0': 'start_lon',
#        'lat1': 'end_lat',
#        'lng1': 'ending_lon',
#        'alt0': None,
#        'alt1': None},
#       'isVisible': True,
#       'visConfig': {'opacity': 0.8,
#        'thickness': 2,
#        'colorRange': {'name': 'Global Warming',
#         'type': 'sequential',
#         'category': 'Uber',
#         'colors': ['#5A1846',
#          '#900C3F',
#          '#C70039',
#          '#E3611C',
#          '#F1920E',
#          '#FFC300']},
#        'sizeRange': [0, 10],
#        'targetColor': None,
#        'elevationScale': 1},
#       'hidden': False,
#       'textLabel': [{'field': None,
#         'color': [255, 255, 255],
#         'size': 18,
#         'offset': [0, 0],
#         'anchor': 'start',
#         'alignment': 'center'}]},
#      'visualChannels': {'colorField': None,
#       'colorScale': 'quantile',
#       'sizeField': None,
#       'sizeScale': 'linear'}}],
#    'interactionConfig': {'tooltip': {'fieldsToShow': {'iNat': [{'name': 'Latitude',
#         'format': None},
#        {'name': 'Longitude', 'format': None}],
#       'boundingbox': [{'name': 'point', 'format': None}]},
#      'compareMode': False,
#      'compareType': 'absolute',
#      'enabled': True},
#     'brush': {'size': 0.5, 'enabled': False},
#     'geocoder': {'enabled': False},
#     'coordinate': {'enabled': False}},
#    'layerBlending': 'normal',
#    'splitMaps': [],
#    'animationConfig': {'currentTime': None, 'speed': 1}},
#   'mapState': {'bearing': 0,
#    'dragRotate': False,
#    'latitude': 39.485074091586995,
#    'longitude': -121.49833176779376,
#    'pitch': 0,
#    'zoom': 5.055357102887484,
#    'isSplit': False},
#   'mapStyle': {'styleType': 'dark',
#    'topLayerGroups': {},
#    'visibleLayerGroups': {'label': True,
#     'road': True,
#     'border': False,
#     'building': True,
#     'water': True,
#     'land': True,
#     '3d building': False},
#    'threeDBuildingColor': [9.665468314072013,
#     17.18305478057247,
#     31.1442867897876],
#    'mapStyles': {}}}}

# %%
display(map_2)
# Out:
# KeplerGl(data={'eBird': {'index': [4868541, 980204, 3913806, 1884397, 4713939, 5034367, 3761760, 1692624, 3747…

# %%
ebird_config = {'version': 'v1',
 'config': {'visState': {'filters': [],
   'layers': [{'id': 'g1izjtk',
     'type': 'grid',
     'config': {'dataId': 'eBird',
      'label': 'Point',
      'color': [183, 136, 94],
      'highlightColor': [252, 242, 26, 255],
      'columns': {'lat': 'Latitude', 'lng': 'Longitude'},
      'isVisible': True,
      'visConfig': {'opacity': 0.8,
       'worldUnitSize': 2,
       'colorRange': {'name': 'Global Warming',
        'type': 'sequential',
        'category': 'Uber',
        'colors': ['#5A1846',
         '#900C3F',
         '#C70039',
         '#E3611C',
         '#F1920E',
         '#FFC300']},
       'coverage': 1,
       'sizeRange': [0, 500],
       'percentile': [0, 100],
       'elevationPercentile': [0, 100],
       'elevationScale': 5,
       'enableElevationZoomFactor': True,
       'colorAggregation': 'count',
       'sizeAggregation': 'count',
       'enable3d': False},
      'hidden': False,
      'textLabel': [{'field': None,
        'color': [255, 255, 255],
        'size': 18,
        'offset': [0, 0],
        'anchor': 'start',
        'alignment': 'center'}]},
     'visualChannels': {'colorField': None,
      'colorScale': 'quantile',
      'sizeField': None,
      'sizeScale': 'linear'}},
    {'id': '6b0ba29',
     'type': 'line',
     'config': {'dataId': 'boundingbox',
      'label': 'Bounding Box',
      'color': [179, 173, 158],
      'highlightColor': [252, 242, 26, 255],
      'columns': {'lat0': 'starting_lat',
       'lng0': 'start_lon',
       'lat1': 'end_lat',
       'lng1': 'ending_lon',
       'alt0': None,
       'alt1': None},
      'isVisible': True,
      'visConfig': {'opacity': 0.8,
       'thickness': 2,
       'colorRange': {'name': 'Global Warming',
        'type': 'sequential',
        'category': 'Uber',
        'colors': ['#5A1846',
         '#900C3F',
         '#C70039',
         '#E3611C',
         '#F1920E',
         '#FFC300']},
       'sizeRange': [0, 10],
       'targetColor': None,
       'elevationScale': 1},
      'hidden': False,
      'textLabel': [{'field': None,
        'color': [255, 255, 255],
        'size': 18,
        'offset': [0, 0],
        'anchor': 'start',
        'alignment': 'center'}]},
     'visualChannels': {'colorField': None,
      'colorScale': 'quantile',
      'sizeField': None,
      'sizeScale': 'linear'}}],
   'interactionConfig': {'tooltip': {'fieldsToShow': {'eBird': [{'name': 'Latitude',
        'format': None},
       {'name': 'Longitude', 'format': None}],
      'boundingbox': [{'name': 'point', 'format': None}]},
     'compareMode': False,
     'compareType': 'absolute',
     'enabled': True},
    'brush': {'size': 0.5, 'enabled': False},
    'geocoder': {'enabled': False},
    'coordinate': {'enabled': False}},
   'layerBlending': 'normal',
   'splitMaps': [],
   'animationConfig': {'currentTime': None, 'speed': 1}},
  'mapState': {'bearing': 0,
   'dragRotate': False,
   'latitude': 40.42855188240014,
   'longitude': -119.15654671361716,
   'pitch': 0,
   'zoom': 5.337663235736472,
   'isSplit': False},
  'mapStyle': {'styleType': 'dark',
   'topLayerGroups': {},
   'visibleLayerGroups': {'label': True,
    'road': True,
    'border': False,
    'building': True,
    'water': True,
    'land': True,
    '3d building': False},
   'threeDBuildingColor': [9.665468314072013,
    17.18305478057247,
    31.1442867897876],
   'mapStyles': {}}}}

# %%
map_2.save_to_html(file_name='ebird_0.html', config=ebird_config)
# Out:
# Map saved to ebird_0.html!

# %%
iNat_config = {'version': 'v1',
 'config': {'visState': {'filters': [],
   'layers': [{'id': '6tb43j',
     'type': 'grid',
     'config': {'dataId': 'iNat',
      'label': 'Point',
      'color': [130, 154, 227],
      'highlightColor': [252, 242, 26, 255],
      'columns': {'lat': 'Latitude', 'lng': 'Longitude'},
      'isVisible': True,
      'visConfig': {'opacity': 0.8,
       'worldUnitSize': 2,
       'colorRange': {'name': 'Global Warming',
        'type': 'sequential',
        'category': 'Uber',
        'colors': ['#5A1846',
         '#900C3F',
         '#C70039',
         '#E3611C',
         '#F1920E',
         '#FFC300']},
       'coverage': 1,
       'sizeRange': [0, 500],
       'percentile': [0, 100],
       'elevationPercentile': [0, 100],
       'elevationScale': 5,
       'enableElevationZoomFactor': True,
       'colorAggregation': 'count',
       'sizeAggregation': 'count',
       'enable3d': False},
      'hidden': False,
      'textLabel': [{'field': None,
        'color': [255, 255, 255],
        'size': 18,
        'offset': [0, 0],
        'anchor': 'start',
        'alignment': 'center'}]},
     'visualChannels': {'colorField': None,
      'colorScale': 'quantile',
      'sizeField': None,
      'sizeScale': 'linear'}},
    {'id': 'il8svz',
     'type': 'line',
     'config': {'dataId': 'boundingbox',
      'label': 'BoundingBox',
      'color': [136, 87, 44],
      'highlightColor': [252, 242, 26, 255],
      'columns': {'lat0': 'starting_lat',
       'lng0': 'start_lon',
       'lat1': 'end_lat',
       'lng1': 'ending_lon',
       'alt0': None,
       'alt1': None},
      'isVisible': True,
      'visConfig': {'opacity': 0.8,
       'thickness': 2,
       'colorRange': {'name': 'Global Warming',
        'type': 'sequential',
        'category': 'Uber',
        'colors': ['#5A1846',
         '#900C3F',
         '#C70039',
         '#E3611C',
         '#F1920E',
         '#FFC300']},
       'sizeRange': [0, 10],
       'targetColor': None,
       'elevationScale': 1},
      'hidden': False,
      'textLabel': [{'field': None,
        'color': [255, 255, 255],
        'size': 18,
        'offset': [0, 0],
        'anchor': 'start',
        'alignment': 'center'}]},
     'visualChannels': {'colorField': None,
      'colorScale': 'quantile',
      'sizeField': None,
      'sizeScale': 'linear'}}],
   'interactionConfig': {'tooltip': {'fieldsToShow': {'iNat': [{'name': 'Latitude',
        'format': None},
       {'name': 'Longitude', 'format': None}],
      'boundingbox': [{'name': 'point', 'format': None}]},
     'compareMode': False,
     'compareType': 'absolute',
     'enabled': True},
    'brush': {'size': 0.5, 'enabled': False},
    'geocoder': {'enabled': False},
    'coordinate': {'enabled': False}},
   'layerBlending': 'normal',
   'splitMaps': [],
   'animationConfig': {'currentTime': None, 'speed': 1}},
  'mapState': {'bearing': 0,
   'dragRotate': False,
   'latitude': 39.485074091586995,
   'longitude': -121.49833176779376,
   'pitch': 0,
   'zoom': 5.055357102887484,
   'isSplit': False},
  'mapStyle': {'styleType': 'dark',
   'topLayerGroups': {},
   'visibleLayerGroups': {'label': True,
    'road': True,
    'border': False,
    'building': True,
    'water': True,
    'land': True,
    '3d building': False},
   'threeDBuildingColor': [9.665468314072013,
    17.18305478057247,
    31.1442867897876],
   'mapStyles': {}}}}

# %%
map_1.save_to_html(file_name='iNat_1.html', config=iNat_config)
# Out:
# Map saved to iNat_1.html!
