# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/eBird/ebd_US-CA_201901_201912_relApr-2023/ebd_US-CA_201901_201912_relApr-2023.txt', sep='\t')
# Out:
# /var/folders/ms/2ygwp03d4b5526gc0h51spqh0000gn/T/ipykernel_91144/2494448556.py:1: DtypeWarning: Columns (9,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/eBird/ebd_US-CA_201901_201912_relApr-2023/ebd_US-CA_201901_201912_relApr-2023.txt', sep='\t')

# %%
df.columns
# Out:
# Index(['GLOBAL UNIQUE IDENTIFIER', 'LAST EDITED DATE', 'TAXONOMIC ORDER',
#        'CATEGORY', 'TAXON CONCEPT ID', 'COMMON NAME', 'SCIENTIFIC NAME',
#        'SUBSPECIES COMMON NAME', 'SUBSPECIES SCIENTIFIC NAME', 'EXOTIC CODE',
#        'OBSERVATION COUNT', 'BREEDING CODE', 'BREEDING CATEGORY',
#        'BEHAVIOR CODE', 'AGE/SEX', 'COUNTRY', 'COUNTRY CODE', 'STATE',
#        'STATE CODE', 'COUNTY', 'COUNTY CODE', 'IBA CODE', 'BCR CODE',
#        'USFWS CODE', 'ATLAS BLOCK', 'LOCALITY', 'LOCALITY ID', 'LOCALITY TYPE',
#        'LATITUDE', 'LONGITUDE', 'OBSERVATION DATE',
#        'TIME OBSERVATIONS STARTED', 'OBSERVER ID', 'SAMPLING EVENT IDENTIFIER',
#        'PROTOCOL TYPE', 'PROTOCOL CODE', 'PROJECT CODE', 'DURATION MINUTES',
#        'EFFORT DISTANCE KM', 'EFFORT AREA HA', 'NUMBER OBSERVERS',
#        'ALL SPECIES REPORTED', 'GROUP IDENTIFIER', 'HAS MEDIA', 'APPROVED',
#        'REVIEWED', 'REASON', 'TRIP COMMENTS', 'SPECIES COMMENTS',
#        'Unnamed: 49'],
#       dtype='object')

# %%
df.iloc[0, :]
# Out:
# GLOBAL UNIQUE IDENTIFIER      URN:CornellLabOfOrnithology:EBIRD:OBS698024716
# LAST EDITED DATE                                  2021-08-05 02:45:57.629774
# TAXONOMIC ORDER                                                         8078
# CATEGORY                                                                spuh
# TAXON CONCEPT ID                                            avibase-CA08045E
# COMMON NAME                                                    Accipiter sp.
# SCIENTIFIC NAME                                                Accipiter sp.
# SUBSPECIES COMMON NAME                                                   NaN
# SUBSPECIES SCIENTIFIC NAME                                               NaN
# EXOTIC CODE                                                              NaN
# OBSERVATION COUNT                                                          1
# BREEDING CODE                                                            NaN
# BREEDING CATEGORY                                                        NaN
# BEHAVIOR CODE                                                            NaN
# AGE/SEX                                                                  NaN
# COUNTRY                                                        United States
# COUNTRY CODE                                                              US
# STATE                                                             California
# STATE CODE                                                             US-CA
# COUNTY                                                               Alameda
# COUNTY CODE                                                        US-CA-001
# IBA CODE                                                           US-CA_141
# BCR CODE                                                                 NaN
# USFWS CODE                                                               NaN
# ATLAS BLOCK                                                              NaN
# LOCALITY                                                     Albany Mudflats
# LOCALITY ID                                                          L484238
# LOCALITY TYPE                                                              H
# LATITUDE                                                           37.892331
# LONGITUDE                                                          -122.3118
# OBSERVATION DATE                                                  2019-01-13
# TIME OBSERVATIONS STARTED                                           12:19:00
# OBSERVER ID                                                       obsr181345
# SAMPLING EVENT IDENTIFIER                                          S51647358
# PROTOCOL TYPE                                                      Traveling
# PROTOCOL CODE                                                            P22
# PROJECT CODE                                                           EBIRD
# DURATION MINUTES                                                       124.0
# EFFORT DISTANCE KM                                                     1.713
# EFFORT AREA HA                                                           NaN
# NUMBER OBSERVERS                                                         3.0
# ALL SPECIES REPORTED                                                       1
# GROUP IDENTIFIER                                                         NaN
# HAS MEDIA                                                                  0
# APPROVED                                                                   1
# REVIEWED                                                                   0
# REASON                                                                   NaN
# TRIP COMMENTS                                                            NaN
# SPECIES COMMENTS                                                         NaN
# Unnamed: 49                                                              NaN
# Name: 0, dtype: object

# %%
df.iloc[0:10, :].T
# Out:
#                                                                          0  \
# GLOBAL UNIQUE IDENTIFIER    URN:CornellLabOfOrnithology:EBIRD:OBS698024716
# LAST EDITED DATE                                2021-08-05 02:45:57.629774
# TAXONOMIC ORDER                                                       8078
# CATEGORY                                                              spuh
# TAXON CONCEPT ID                                          avibase-CA08045E
# COMMON NAME                                                  Accipiter sp.
# SCIENTIFIC NAME                                              Accipiter sp.
# SUBSPECIES COMMON NAME                                                 NaN
# SUBSPECIES SCIENTIFIC NAME                                             NaN
# EXOTIC CODE                                                            NaN
# OBSERVATION COUNT                                                        1
# BREEDING CODE                                                          NaN
# BREEDING CATEGORY                                                      NaN
# BEHAVIOR CODE                                                          NaN
# AGE/SEX                                                                NaN
# COUNTRY                                                      United States
# COUNTRY CODE                                                            US
# STATE                                                           California
# STATE CODE                                                           US-CA
# COUNTY                                                             Alameda
# COUNTY CODE                                                      US-CA-001
# IBA CODE                                                         US-CA_141
# BCR CODE                                                               NaN
# USFWS CODE                                                             NaN
# ATLAS BLOCK                                                            NaN
# LOCALITY                                                   Albany Mudflats
# LOCALITY ID                                                        L484238
# LOCALITY TYPE                                                            H
# LATITUDE                                                         37.892331
# LONGITUDE                                                        -122.3118
# OBSERVATION DATE                                                2019-01-13
# TIME OBSERVATIONS STARTED                                         12:19:00
# OBSERVER ID                                                     obsr181345
# SAMPLING EVENT IDENTIFIER                                        S51647358
# PROTOCOL TYPE                                                    Traveling
# PROTOCOL CODE                                                          P22
# PROJECT CODE                                                         EBIRD
# DURATION MINUTES                                                     124.0
# EFFORT DISTANCE KM                                                   1.713
# EFFORT AREA HA                                                         NaN
# NUMBER OBSERVERS                                                       3.0
# ALL SPECIES REPORTED                                                     1
# GROUP IDENTIFIER                                                       NaN
# HAS MEDIA                                                                0
# APPROVED                                                                 1
# REVIEWED                                                                 0
# REASON                                                                 NaN
# TRIP COMMENTS                                                          NaN
# SPECIES COMMENTS                                                       NaN
# Unnamed: 49                                                            NaN
#
#                                                                          1  \
# GLOBAL UNIQUE IDENTIFIER    URN:CornellLabOfOrnithology:EBIRD:OBS692730992
# LAST EDITED DATE                                       2019-01-02 13:51:35
# TAXONOMIC ORDER                                                       8078
# CATEGORY                                                              spuh
# TAXON CONCEPT ID                                          avibase-CA08045E
# COMMON NAME                                                  Accipiter sp.
# SCIENTIFIC NAME                                              Accipiter sp.
# SUBSPECIES COMMON NAME                                                 NaN
# SUBSPECIES SCIENTIFIC NAME                                             NaN
# EXOTIC CODE                                                            NaN
# OBSERVATION COUNT                                                        X
# BREEDING CODE                                                          NaN
# BREEDING CATEGORY                                                      NaN
# BEHAVIOR CODE                                                          NaN
# AGE/SEX                                                                NaN
# COUNTRY                                                      United States
# COUNTRY CODE                                                            US
# STATE                                                           California
# STATE CODE                                                           US-CA
# COUNTY                                                             Alameda
# COUNTY CODE                                                      US-CA-001
# IBA CODE                                                         US-CA_141
# BCR CODE                                                               NaN
# USFWS CODE                                                             NaN
# ATLAS BLOCK                                                            NaN
# LOCALITY                                                 North Basin Strip
# LOCALITY ID                                                       L5188893
# LOCALITY TYPE                                                            P
# LATITUDE                                                          37.87127
# LONGITUDE                                                       -122.30789
# OBSERVATION DATE                                                2019-01-01
# TIME OBSERVATIONS STARTED                                              NaN
# OBSERVER ID                                                     obsr210310
# SAMPLING EVENT IDENTIFIER                                        S51219898
# PROTOCOL TYPE                                                   Incidental
# PROTOCOL CODE                                                          P20
# PROJECT CODE                                                         EBIRD
# DURATION MINUTES                                                       NaN
# EFFORT DISTANCE KM                                                     NaN
# EFFORT AREA HA                                                         NaN
# NUMBER OBSERVERS                                                       NaN
# ALL SPECIES REPORTED                                                     0
# GROUP IDENTIFIER                                                       NaN
# HAS MEDIA                                                                0
# APPROVED                                                                 1
# REVIEWED                                                                 0
# REASON                                                                 NaN
# TRIP COMMENTS                                                          NaN
# SPECIES COMMENTS                                                       NaN
# Unnamed: 49                                                            NaN
#
#                                                                          2  \
# GLOBAL UNIQUE IDENTIFIER    URN:CornellLabOfOrnithology:EBIRD:OBS702777051
# LAST EDITED DATE                                       2019-01-27 21:53:18
# TAXONOMIC ORDER                                                       8078
# CATEGORY                                                              spuh
# TAXON CONCEPT ID                                          avibase-CA08045E
# COMMON NAME                                                  Accipiter sp.
# SCIENTIFIC NAME                                              Accipiter sp.
# SUBSPECIES COMMON NAME                                                 NaN
# SUBSPECIES SCIENTIFIC NAME                                             NaN
# EXOTIC CODE                                                            NaN
# OBSERVATION COUNT                                                        1
# BREEDING CODE                                                          NaN
# BREEDING CATEGORY                                                      NaN
# BEHAVIOR CODE                                                          NaN
# AGE/SEX                                                                NaN
# COUNTRY                                                      United States
# COUNTRY CODE                                                            US
# STATE                                                           California
# STATE CODE                                                           US-CA
# COUNTY                                                             Alameda
# COUNTY CODE                                                      US-CA-001
# IBA CODE                                                               NaN
# BCR CODE                                                              32.0
# USFWS CODE                                                             NaN
# ATLAS BLOCK                                                            NaN
# LOCALITY                                  Mountain View Cemetery (ALA Co.)
# LOCALITY ID                                                       L3104978
# LOCALITY TYPE                                                            H
# LATITUDE                                                         37.834029
# LONGITUDE                                                      -122.238747
# OBSERVATION DATE                                                2019-01-25
# TIME OBSERVATIONS STARTED                                         14:30:00
# OBSERVER ID                                                    obsr1201869
# SAMPLING EVENT IDENTIFIER                                        S52039859
# PROTOCOL TYPE                                                    Traveling
# PROTOCOL CODE                                                          P22
# PROJECT CODE                                                         EBIRD
# DURATION MINUTES                                                      90.0
# EFFORT DISTANCE KM                                                   1.609
# EFFORT AREA HA                                                         NaN
# NUMBER OBSERVERS                                                       2.0
# ALL SPECIES REPORTED                                                     1
# GROUP IDENTIFIER                                                  G3804122
# HAS MEDIA                                                                0
# APPROVED                                                                 1
# REVIEWED                                                                 0
# REASON                                                                 NaN
# TRIP COMMENTS                                                          NaN
# SPECIES COMMENTS                                                       NaN
# Unnamed: 49                                                            NaN
#
#                                                                          3  \
# GLOBAL UNIQUE IDENTIFIER    URN:CornellLabOfOrnithology:EBIRD:OBS697015061
# LAST EDITED DATE                                2021-03-18 00:43:01.179135
# TAXONOMIC ORDER                                                       8078
# CATEGORY                                                              spuh
# TAXON CONCEPT ID                                          avibase-CA08045E
# COMMON NAME                                                  Accipiter sp.
# SCIENTIFIC NAME                                              Accipiter sp.
# SUBSPECIES COMMON NAME                                                 NaN
# SUBSPECIES SCIENTIFIC NAME                                             NaN
# EXOTIC CODE                                                            NaN
# OBSERVATION COUNT                                                        1
# BREEDING CODE                                                          NaN
# BREEDING CATEGORY                                                      NaN
# BEHAVIOR CODE                                                          NaN
# AGE/SEX                                                                NaN
# COUNTRY                                                      United States
# COUNTRY CODE                                                            US
# STATE                                                           California
# STATE CODE                                                           US-CA
# COUNTY                                                             Alameda
# COUNTY CODE                                                      US-CA-001
# IBA CODE                                                               NaN
# BCR CODE                                                              32.0
# USFWS CODE                                                             NaN
# ATLAS BLOCK                                                            NaN
# LOCALITY                           Arroyo las Positas Creek and Bike Trail
# LOCALITY ID                                                       L8409194
# LOCALITY TYPE                                                            P
# LATITUDE                                                         37.695328
# LONGITUDE                                                      -121.844741
# OBSERVATION DATE                                                2019-01-10
# TIME OBSERVATIONS STARTED                                         09:30:00
# OBSERVER ID                                                     obsr543710
# SAMPLING EVENT IDENTIFIER                                        S51563658
# PROTOCOL TYPE                                                    Traveling
# PROTOCOL CODE                                                          P22
# PROJECT CODE                                                         EBIRD
# DURATION MINUTES                                                     540.0
# EFFORT DISTANCE KM                                                   2.414
# EFFORT AREA HA                                                         NaN
# NUMBER OBSERVERS                                                       2.0
# ALL SPECIES REPORTED                                                     1
# GROUP IDENTIFIER                                                       NaN
# HAS MEDIA                                                                0
# APPROVED                                                                 1
# REVIEWED                                                                 0
# REASON                                                                 NaN
# TRIP COMMENTS                                                          NaN
# SPECIES COMMENTS                                                       NaN
# Unnamed: 49                                                            NaN
#
#                                                                          4  \
# GLOBAL UNIQUE IDENTIFIER    URN:CornellLabOfOrnithology:EBIRD:OBS703645792
# LAST EDITED DATE                                       2020-01-27 18:00:05
# TAXONOMIC ORDER                                                       8078
# CATEGORY                                                              spuh
# TAXON CONCEPT ID                                          avibase-CA08045E
# COMMON NAME                                                  Accipiter sp.
# SCIENTIFIC NAME                                              Accipiter sp.
# SUBSPECIES COMMON NAME                                                 NaN
# SUBSPECIES SCIENTIFIC NAME                                             NaN
# EXOTIC CODE                                                            NaN
# OBSERVATION COUNT                                                        1
# BREEDING CODE                                                          NaN
# BREEDING CATEGORY                                                      NaN
# BEHAVIOR CODE                                                          NaN
# AGE/SEX                                                                NaN
# COUNTRY                                                      United States
# COUNTRY CODE                                                            US
# STATE                                                           California
# STATE CODE                                                           US-CA
# COUNTY                                                             Alameda
# COUNTY CODE                                                      US-CA-001
# IBA CODE                                                               NaN
# BCR CODE                                                              32.0
# USFWS CODE                                                             NaN
# ATLAS BLOCK                                                            NaN
# LOCALITY                                  Mountain View Cemetery (ALA Co.)
# LOCALITY ID                                                       L3104978
# LOCALITY TYPE                                                            H
# LATITUDE                                                         37.834029
# LONGITUDE                                                      -122.238747
# OBSERVATION DATE                                                2019-01-25
# TIME OBSERVATIONS STARTED                                         14:30:00
# OBSERVER ID                                                    obsr1199018
# SAMPLING EVENT IDENTIFIER                                        S52110098
# PROTOCOL TYPE                                                    Traveling
# PROTOCOL CODE                                                          P22
# PROJECT CODE                                                         EBIRD
# DURATION MINUTES                                                      90.0
# EFFORT DISTANCE KM                                                   1.609
# EFFORT AREA HA                                                         NaN
# NUMBER OBSERVERS                                                       2.0
# ALL SPECIES REPORTED                                                     1
# GROUP IDENTIFIER                                                  G3804122
# HAS MEDIA                                                                0
# APPROVED                                                                 1
# REVIEWED                                                                 0
# REASON                                                                 NaN
# TRIP COMMENTS                                                          NaN
# SPECIES COMMENTS                                                       NaN
# Unnamed: 49                                                            NaN
#
#                                                                          5  \
# GLOBAL UNIQUE IDENTIFIER    URN:CornellLabOfOrnithology:EBIRD:OBS699791078
# LAST EDITED DATE                                2021-04-01 02:10:03.093984
# TAXONOMIC ORDER                                                       8078
# CATEGORY                                                              spuh
# TAXON CONCEPT ID                                          avibase-CA08045E
# COMMON NAME                                                  Accipiter sp.
# SCIENTIFIC NAME                                              Accipiter sp.
# SUBSPECIES COMMON NAME                                                 NaN
# SUBSPECIES SCIENTIFIC NAME                                             NaN
# EXOTIC CODE                                                            NaN
# OBSERVATION COUNT                                                        1
# BREEDING CODE                                                          NaN
# BREEDING CATEGORY                                                      NaN
# BEHAVIOR CODE                                                          NaN
# AGE/SEX                                                                NaN
# COUNTRY                                                      United States
# COUNTRY CODE                                                            US
# STATE                                                           California
# STATE CODE                                                           US-CA
# COUNTY                                                             Alameda
# COUNTY CODE                                                      US-CA-001
# IBA CODE                                                               NaN
# BCR CODE                                                              32.0
# USFWS CODE                                                             NaN
# ATLAS BLOCK                                                            NaN
# LOCALITY                              Heron rookery at Jackson St. Oakland
# LOCALITY ID                                                       L4508840
# LOCALITY TYPE                                                            P
# LATITUDE                                                         37.801218
# LONGITUDE                                                      -122.266052
# OBSERVATION DATE                                                2019-01-17
# TIME OBSERVATIONS STARTED                                         16:00:00
# OBSERVER ID                                                     obsr291421
# SAMPLING EVENT IDENTIFIER                                        S51796438
# PROTOCOL TYPE                                                    Traveling
# PROTOCOL CODE                                                          P22
# PROJECT CODE                                                         EBIRD
# DURATION MINUTES                                                      20.0
# EFFORT DISTANCE KM                                                     0.2
# EFFORT AREA HA                                                         NaN
# NUMBER OBSERVERS                                                       1.0
# ALL SPECIES REPORTED                                                     1
# GROUP IDENTIFIER                                                       NaN
# HAS MEDIA                                                                0
# APPROVED                                                                 1
# REVIEWED                                                                 0
# REASON                                                                 NaN
# TRIP COMMENTS                                                          NaN
# SPECIES COMMENTS                                                       NaN
# Unnamed: 49                                                            NaN
#
#                                                                             6  \
# GLOBAL UNIQUE IDENTIFIER       URN:CornellLabOfOrnithology:EBIRD:OBS701988795
# LAST EDITED DATE                                          2019-01-23 17:09:56
# TAXONOMIC ORDER                                                         10835
# CATEGORY                                                              species
# TAXON CONCEPT ID                                             avibase-7E327303
# COMMON NAME                                                  Acorn Woodpecker
# SCIENTIFIC NAME                                       Melanerpes formicivorus
# SUBSPECIES COMMON NAME                                                    NaN
# SUBSPECIES SCIENTIFIC NAME                                                NaN
# EXOTIC CODE                                                               NaN
# OBSERVATION COUNT                                                          10
# BREEDING CODE                                                             NaN
# BREEDING CATEGORY                                                         NaN
# BEHAVIOR CODE                                                             NaN
# AGE/SEX                                                                   NaN
# COUNTRY                                                         United States
# COUNTRY CODE                                                               US
# STATE                                                              California
# STATE CODE                                                              US-CA
# COUNTY                                                                Alameda
# COUNTY CODE                                                         US-CA-001
# IBA CODE                                                            US-CA_140
# BCR CODE                                                                 32.0
# USFWS CODE                                                                NaN
# ATLAS BLOCK                                                               NaN
# LOCALITY                                                       Del Valle EBRP
# LOCALITY ID                                                           L893283
# LOCALITY TYPE                                                               P
# LATITUDE                                                            37.606181
# LONGITUDE                                                         -121.735039
# OBSERVATION DATE                                                   2019-01-23
# TIME OBSERVATIONS STARTED                                            11:15:00
# OBSERVER ID                                                        obsr221174
# SAMPLING EVENT IDENTIFIER                                           S51974732
# PROTOCOL TYPE                                                       Traveling
# PROTOCOL CODE                                                             P22
# PROJECT CODE                                                            EBIRD
# DURATION MINUTES                                                         60.0
# EFFORT DISTANCE KM                                                      0.805
# EFFORT AREA HA                                                            NaN
# NUMBER OBSERVERS                                                          1.0
# ALL SPECIES REPORTED                                                        1
# GROUP IDENTIFIER                                                          NaN
# HAS MEDIA                                                                   0
# APPROVED                                                                    1
# REVIEWED                                                                    0
# REASON                                                                    NaN
# TRIP COMMENTS               Birded around Rocky Ridge VC, mainly looking f...
# SPECIES COMMENTS                                                          NaN
# Unnamed: 49                                                               NaN
#
#                                                                          7  \
# GLOBAL UNIQUE IDENTIFIER    URN:CornellLabOfOrnithology:EBIRD:OBS697576904
# LAST EDITED DATE                                       2019-01-30 00:41:59
# TAXONOMIC ORDER                                                      10835
# CATEGORY                                                           species
# TAXON CONCEPT ID                                          avibase-7E327303
# COMMON NAME                                               Acorn Woodpecker
# SCIENTIFIC NAME                                    Melanerpes formicivorus
# SUBSPECIES COMMON NAME                                                 NaN
# SUBSPECIES SCIENTIFIC NAME                                             NaN
# EXOTIC CODE                                                            NaN
# OBSERVATION COUNT                                                        1
# BREEDING CODE                                                          NaN
# BREEDING CATEGORY                                                      NaN
# BEHAVIOR CODE                                                          NaN
# AGE/SEX                                                                NaN
# COUNTRY                                                      United States
# COUNTRY CODE                                                            US
# STATE                                                           California
# STATE CODE                                                           US-CA
# COUNTY                                                             Alameda
# COUNTY CODE                                                      US-CA-001
# IBA CODE                                                               NaN
# BCR CODE                                                              32.0
# USFWS CODE                                                             NaN
# ATLAS BLOCK                                                            NaN
# LOCALITY                                Claremont Canyon Regional Preserve
# LOCALITY ID                                                        L933409
# LOCALITY TYPE                                                            H
# LATITUDE                                                          37.86613
# LONGITUDE                                                      -122.239573
# OBSERVATION DATE                                                2019-01-12
# TIME OBSERVATIONS STARTED                                         15:19:00
# OBSERVER ID                                                      obsr92733
# SAMPLING EVENT IDENTIFIER                                        S51611148
# PROTOCOL TYPE                                                    Traveling
# PROTOCOL CODE                                                          P22
# PROJECT CODE                                                         EBIRD
# DURATION MINUTES                                                      78.0
# EFFORT DISTANCE KM                                                   1.931
# EFFORT AREA HA                                                         NaN
# NUMBER OBSERVERS                                                       1.0
# ALL SPECIES REPORTED                                                     1
# GROUP IDENTIFIER                                                       NaN
# HAS MEDIA                                                                0
# APPROVED                                                                 1
# REVIEWED                                                                 0
# REASON                                                                 NaN
# TRIP COMMENTS                                                          NaN
# SPECIES COMMENTS                                                       NaN
# Unnamed: 49                                                            NaN
#
#                                                                          8  \
# GLOBAL UNIQUE IDENTIFIER    URN:CornellLabOfOrnithology:EBIRD:OBS698385823
# LAST EDITED DATE                                       2019-11-23 20:26:58
# TAXONOMIC ORDER                                                      10835
# CATEGORY                                                           species
# TAXON CONCEPT ID                                          avibase-7E327303
# COMMON NAME                                               Acorn Woodpecker
# SCIENTIFIC NAME                                    Melanerpes formicivorus
# SUBSPECIES COMMON NAME                                                 NaN
# SUBSPECIES SCIENTIFIC NAME                                             NaN
# EXOTIC CODE                                                            NaN
# OBSERVATION COUNT                                                        3
# BREEDING CODE                                                          NaN
# BREEDING CATEGORY                                                      NaN
# BEHAVIOR CODE                                                          NaN
# AGE/SEX                                                                NaN
# COUNTRY                                                      United States
# COUNTRY CODE                                                            US
# STATE                                                           California
# STATE CODE                                                           US-CA
# COUNTY                                                             Alameda
# COUNTY CODE                                                      US-CA-001
# IBA CODE                                                               NaN
# BCR CODE                                                              32.0
# USFWS CODE                                                             NaN
# ATLAS BLOCK                                                            NaN
# LOCALITY                                claremont canyon regional preserve
# LOCALITY ID                                                       L8429705
# LOCALITY TYPE                                                            P
# LATITUDE                                                         37.863654
# LONGITUDE                                                        -122.2444
# OBSERVATION DATE                                                2019-01-13
# TIME OBSERVATIONS STARTED                                         10:15:00
# OBSERVER ID                                                     obsr785502
# SAMPLING EVENT IDENTIFIER                                        S51676967
# PROTOCOL TYPE                                                    Traveling
# PROTOCOL CODE                                                          P22
# PROJECT CODE                                                         EBIRD
# DURATION MINUTES                                                      75.0
# EFFORT DISTANCE KM                                                   3.219
# EFFORT AREA HA                                                         NaN
# NUMBER OBSERVERS                                                       2.0
# ALL SPECIES REPORTED                                                     0
# GROUP IDENTIFIER                                                       NaN
# HAS MEDIA                                                                0
# APPROVED                                                                 1
# REVIEWED                                                                 0
# REASON                                                                 NaN
# TRIP COMMENTS                                                          NaN
# SPECIES COMMENTS                                                       NaN
# Unnamed: 49                                                            NaN
#
#                                                                          9
# GLOBAL UNIQUE IDENTIFIER    URN:CornellLabOfOrnithology:EBIRD:OBS693830964
# LAST EDITED DATE                                2021-03-25 11:05:49.608382
# TAXONOMIC ORDER                                                      10835
# CATEGORY                                                           species
# TAXON CONCEPT ID                                          avibase-7E327303
# COMMON NAME                                               Acorn Woodpecker
# SCIENTIFIC NAME                                    Melanerpes formicivorus
# SUBSPECIES COMMON NAME                                                 NaN
# SUBSPECIES SCIENTIFIC NAME                                             NaN
# EXOTIC CODE                                                            NaN
# OBSERVATION COUNT                                                        1
# BREEDING CODE                                                          NaN
# BREEDING CATEGORY                                                      NaN
# BEHAVIOR CODE                                                          NaN
# AGE/SEX                                                                NaN
# COUNTRY                                                      United States
# COUNTRY CODE                                                            US
# STATE                                                           California
# STATE CODE                                                           US-CA
# COUNTY                                                             Alameda
# COUNTY CODE                                                      US-CA-001
# IBA CODE                                                               NaN
# BCR CODE                                                              32.0
# USFWS CODE                                                             NaN
# ATLAS BLOCK                                                            NaN
# LOCALITY                                               (37.8907,-122.2716)
# LOCALITY ID                                                       L8368976
# LOCALITY TYPE                                                            P
# LATITUDE                                                          37.89068
# LONGITUDE                                                      -122.271627
# OBSERVATION DATE                                                2019-01-04
# TIME OBSERVATIONS STARTED                                         15:35:00
# OBSERVER ID                                                    obsr1182273
# SAMPLING EVENT IDENTIFIER                                        S51317719
# PROTOCOL TYPE                                                   Stationary
# PROTOCOL CODE                                                          P21
# PROJECT CODE                                                         EBIRD
# DURATION MINUTES                                                       2.0
# EFFORT DISTANCE KM                                                     NaN
# EFFORT AREA HA                                                         NaN
# NUMBER OBSERVERS                                                       1.0
# ALL SPECIES REPORTED                                                     1
# GROUP IDENTIFIER                                                  G3722451
# HAS MEDIA                                                                0
# APPROVED                                                                 1
# REVIEWED                                                                 0
# REASON                                                                 NaN
# TRIP COMMENTS                                                          NaN
# SPECIES COMMENTS                                                       NaN
# Unnamed: 49                                                            NaN

# %%
df['COUNTRY'].value_counts()
# Out:
# United States    8694926
# Name: COUNTRY, dtype: int64

# %%
df['STATE'].value_counts()
# Out:
# California    8694926
# Name: STATE, dtype: int64

# %%
df['STATE CODE'].value_counts()
# Out:
# US-CA    8694926
# Name: STATE CODE, dtype: int64

# %%
selected_columns = [
    'TAXON CONCEPT ID',
    'COMMON NAME', 'SCIENTIFIC NAME',
    'OBSERVATION COUNT',
    'LATITUDE', 'LONGITUDE', 'OBSERVATION DATE'
]

# %%
df_filtered = df[
    (df['LATITUDE']>=36.4701132878)
    &
    (df['LATITUDE']<=42.009518)
    &
    (df['LONGITUDE']>= -124.409591)
    &
    (df['LONGITUDE']<= -114.131211)
][selected_columns].copy()

# %%
df_filtered.shape
# Out:
# (5168169, 7)

# %% [markdown]
# ## Reduction from 8.69 million to 5.16 million for the bounding box

# %%
df_filtered['OBSERVATION COUNT'].value_counts()
# Out:
# 1       1700308
# 2        978793
# 3        457009
# 4        344981
# 5        239338
#          ...
# 852           1
# 4750          1
# 1061          1
# 2255          1
# 988           1
# Name: OBSERVATION COUNT, Length: 1431, dtype: int64

# %%
df_filtered[~df_filtered['OBSERVATION COUNT'].str.isnumeric()]['OBSERVATION COUNT'].value_counts()
# Out:
# X    107218
# Name: OBSERVATION COUNT, dtype: int64

# %%
df_filtered[df_filtered['OBSERVATION COUNT'].str.isnumeric()]['OBSERVATION COUNT'].values[0]
# Out:
# '1'

# %%
df_filtered['OBSERVATION COUNT'] = df_filtered['OBSERVATION COUNT'].apply(lambda x: 1 if x == 'X' else int(x))

# %%
df_filtered['OBSERVATION COUNT'].value_counts()
# Out:
# 1       1807526
# 2        978793
# 3        457009
# 4        344981
# 5        239338
#          ...
# 852           1
# 4750          1
# 1061          1
# 2255          1
# 473           1
# Name: OBSERVATION COUNT, Length: 1430, dtype: int64

# %%
df_filtered.shape
# Out:
# (5168169, 7)

# %%
df_filtered
# Out:
#          TAXON CONCEPT ID            COMMON NAME     SCIENTIFIC NAME  \
# 0        avibase-CA08045E          Accipiter sp.       Accipiter sp.
# 1        avibase-CA08045E          Accipiter sp.       Accipiter sp.
# 2        avibase-CA08045E          Accipiter sp.       Accipiter sp.
# 3        avibase-CA08045E          Accipiter sp.       Accipiter sp.
# 4        avibase-CA08045E          Accipiter sp.       Accipiter sp.
# ...                   ...                    ...                 ...
# 8694921  avibase-BC5A9498  Yellow-rumped Warbler  Setophaga coronata
# 8694922  avibase-BC5A9498  Yellow-rumped Warbler  Setophaga coronata
# 8694923  avibase-BC5A9498  Yellow-rumped Warbler  Setophaga coronata
# 8694924  avibase-BC5A9498  Yellow-rumped Warbler  Setophaga coronata
# 8694925  avibase-BC5A9498  Yellow-rumped Warbler  Setophaga coronata
#
#          OBSERVATION COUNT   LATITUDE   LONGITUDE OBSERVATION DATE
# 0                        1  37.892331 -122.311800       2019-01-13
# 1                        1  37.871270 -122.307890       2019-01-01
# 2                        1  37.834029 -122.238747       2019-01-25
# 3                        1  37.695328 -121.844741       2019-01-10
# 4                        1  37.834029 -122.238747       2019-01-25
# ...                    ...        ...         ...              ...
# 8694921                 13  39.427357 -121.130547       2019-12-26
# 8694922                  4  39.189706 -121.593404       2019-12-19
# 8694923                  4  39.264460 -121.602397       2019-12-19
# 8694924                  4  39.264460 -121.602397       2019-12-19
# 8694925                 17  39.265221 -121.534367       2019-12-20
#
# [5168169 rows x 7 columns]

# %%
df_filtered['MONTH'] = df_filtered['OBSERVATION DATE'].apply(lambda x: x[5:7])

# %%
df_filtered
# Out:
#          TAXON CONCEPT ID            COMMON NAME     SCIENTIFIC NAME  \
# 0        avibase-CA08045E          Accipiter sp.       Accipiter sp.
# 1        avibase-CA08045E          Accipiter sp.       Accipiter sp.
# 2        avibase-CA08045E          Accipiter sp.       Accipiter sp.
# 3        avibase-CA08045E          Accipiter sp.       Accipiter sp.
# 4        avibase-CA08045E          Accipiter sp.       Accipiter sp.
# ...                   ...                    ...                 ...
# 8694921  avibase-BC5A9498  Yellow-rumped Warbler  Setophaga coronata
# 8694922  avibase-BC5A9498  Yellow-rumped Warbler  Setophaga coronata
# 8694923  avibase-BC5A9498  Yellow-rumped Warbler  Setophaga coronata
# 8694924  avibase-BC5A9498  Yellow-rumped Warbler  Setophaga coronata
# 8694925  avibase-BC5A9498  Yellow-rumped Warbler  Setophaga coronata
#
#          OBSERVATION COUNT   LATITUDE   LONGITUDE OBSERVATION DATE MONTH
# 0                        1  37.892331 -122.311800       2019-01-13    01
# 1                        1  37.871270 -122.307890       2019-01-01    01
# 2                        1  37.834029 -122.238747       2019-01-25    01
# 3                        1  37.695328 -121.844741       2019-01-10    01
# 4                        1  37.834029 -122.238747       2019-01-25    01
# ...                    ...        ...         ...              ...   ...
# 8694921                 13  39.427357 -121.130547       2019-12-26    12
# 8694922                  4  39.189706 -121.593404       2019-12-19    12
# 8694923                  4  39.264460 -121.602397       2019-12-19    12
# 8694924                  4  39.264460 -121.602397       2019-12-19    12
# 8694925                 17  39.265221 -121.534367       2019-12-20    12
#
# [5168169 rows x 8 columns]

# %%
df_filtered['AVIBASEID'] = df_filtered['TAXON CONCEPT ID'].apply(lambda x: x[8:])

# %%
df_filtered
# Out:
#          TAXON CONCEPT ID            COMMON NAME     SCIENTIFIC NAME  \
# 0        avibase-CA08045E          Accipiter sp.       Accipiter sp.
# 1        avibase-CA08045E          Accipiter sp.       Accipiter sp.
# 2        avibase-CA08045E          Accipiter sp.       Accipiter sp.
# 3        avibase-CA08045E          Accipiter sp.       Accipiter sp.
# 4        avibase-CA08045E          Accipiter sp.       Accipiter sp.
# ...                   ...                    ...                 ...
# 8694921  avibase-BC5A9498  Yellow-rumped Warbler  Setophaga coronata
# 8694922  avibase-BC5A9498  Yellow-rumped Warbler  Setophaga coronata
# 8694923  avibase-BC5A9498  Yellow-rumped Warbler  Setophaga coronata
# 8694924  avibase-BC5A9498  Yellow-rumped Warbler  Setophaga coronata
# 8694925  avibase-BC5A9498  Yellow-rumped Warbler  Setophaga coronata
#
#          OBSERVATION COUNT   LATITUDE   LONGITUDE OBSERVATION DATE MONTH  \
# 0                        1  37.892331 -122.311800       2019-01-13    01
# 1                        1  37.871270 -122.307890       2019-01-01    01
# 2                        1  37.834029 -122.238747       2019-01-25    01
# 3                        1  37.695328 -121.844741       2019-01-10    01
# 4                        1  37.834029 -122.238747       2019-01-25    01
# ...                    ...        ...         ...              ...   ...
# 8694921                 13  39.427357 -121.130547       2019-12-26    12
# 8694922                  4  39.189706 -121.593404       2019-12-19    12
# 8694923                  4  39.264460 -121.602397       2019-12-19    12
# 8694924                  4  39.264460 -121.602397       2019-12-19    12
# 8694925                 17  39.265221 -121.534367       2019-12-20    12
#
#         AVIBASEID
# 0        CA08045E
# 1        CA08045E
# 2        CA08045E
# 3        CA08045E
# 4        CA08045E
# ...           ...
# 8694921  BC5A9498
# 8694922  BC5A9498
# 8694923  BC5A9498
# 8694924  BC5A9498
# 8694925  BC5A9498
#
# [5168169 rows x 9 columns]

# %%
df_filtered['AVIBASEID'].nunique()
# Out:
# 918

# %%
df_inat = pd.read_csv('./df_full_final_saved.csv')

# %%
avibase_ids_finalized = set(df_inat['aviID_short'].values)

# %%
df_filtered.shape
# Out:
# (5168169, 9)

# %%
df_filtered = df_filtered[df_filtered['AVIBASEID'].isin(avibase_ids_finalized)].copy()

# %%
df_filtered.shape
# Out:
# (3219048, 9)

# %% [markdown]
# ## Further reduction in records from 5.16 million to 3.21 million

# %%
df_filtered['AVIBASEID'].nunique()
# Out:
# 135

# %% [markdown]
# ## Found data for 135 of 139 birds from iNaturalist

# %%
df_filtered['OBSERVATION COUNT'].sum()
# Out:
# 160038754

# %%
df_filtered.groupby('MONTH').sum()['OBSERVATION COUNT']
# Out:
# /var/folders/ms/2ygwp03d4b5526gc0h51spqh0000gn/T/ipykernel_91144/3522000221.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_filtered.groupby('MONTH').sum()['OBSERVATION COUNT']
# MONTH
# 01     8911079
# 02     5700652
# 03     9447477
# 04    13734001
# 05    19059295
# 06    36645107
# 07    23786429
# 08     8429690
# 09     4966472
# 10     5045057
# 11    11104564
# 12    13208931
# Name: OBSERVATION COUNT, dtype: int64

# %%
ebird_freq = (100*df_filtered.groupby('MONTH').sum()['OBSERVATION COUNT'])/df_filtered['OBSERVATION COUNT'].sum()
# Out:
# /var/folders/ms/2ygwp03d4b5526gc0h51spqh0000gn/T/ipykernel_91144/2914753535.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ebird_freq = (100*df_filtered.groupby('MONTH').sum()['OBSERVATION COUNT'])/df_filtered['OBSERVATION COUNT'].sum()

# %%
ebird_freq_dict = ebird_freq.to_dict()

# %%
ebird_freq_dict
# Out:
# {'01': 5.568075717460284,
#  '02': 3.562044728241261,
#  '03': 5.903243285685666,
#  '04': 8.581672036761796,
#  '05': 11.909174823992943,
#  '06': 22.89764577897176,
#  '07': 14.862918140439909,
#  '08': 5.267280448834287,
#  '09': 3.1032933435610226,
#  '10': 3.1523970750234658,
#  '11': 6.938671866940429,
#  '12': 8.253582754087176}

# %%
df_ebird_135 = df_filtered.pivot_table(index=['AVIBASEID', 'MONTH'],values='OBSERVATION COUNT', aggfunc='sum').reset_index()

# %%
# No Normalization
df_ebird_135['normalized_observation_count'] = df_ebird_135.apply(
    # lambda x: x['OBSERVATION COUNT']/ebird_freq_dict[x['MONTH']],
    lambda x: x['OBSERVATION COUNT']/1,
    axis=1
).copy()

# %%
df_ebird_135
# Out:
#      AVIBASEID MONTH  OBSERVATION COUNT  normalized_observation_count
# 0     00124D98    01              29377                       29377.0
# 1     00124D98    02              20104                       20104.0
# 2     00124D98    03              22983                       22983.0
# 3     00124D98    04              23999                       23999.0
# 4     00124D98    05              29068                       29068.0
# ...        ...   ...                ...                           ...
# 1572  FFF61080    08               1913                        1913.0
# 1573  FFF61080    09               4658                        4658.0
# 1574  FFF61080    10               1955                        1955.0
# 1575  FFF61080    11               1173                        1173.0
# 1576  FFF61080    12               1329                        1329.0
#
# [1577 rows x 4 columns]

# %%
ebird_135_norm_counts = df_ebird_135.groupby('AVIBASEID').sum()['normalized_observation_count'].to_dict()
# Out:
# /var/folders/ms/2ygwp03d4b5526gc0h51spqh0000gn/T/ipykernel_91144/2495688782.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ebird_135_norm_counts = df_ebird_135.groupby('AVIBASEID').sum()['normalized_observation_count'].to_dict()

# %%
df_ebird_135['fractional_norm_count'] = df_ebird_135.apply(
    lambda x: x['normalized_observation_count']/ebird_135_norm_counts[x['AVIBASEID']],
    axis=1
).copy()

# %%
df_ebird_135
# Out:
#      AVIBASEID MONTH  OBSERVATION COUNT  normalized_observation_count  \
# 0     00124D98    01              29377                       29377.0
# 1     00124D98    02              20104                       20104.0
# 2     00124D98    03              22983                       22983.0
# 3     00124D98    04              23999                       23999.0
# 4     00124D98    05              29068                       29068.0
# ...        ...   ...                ...                           ...
# 1572  FFF61080    08               1913                        1913.0
# 1573  FFF61080    09               4658                        4658.0
# 1574  FFF61080    10               1955                        1955.0
# 1575  FFF61080    11               1173                        1173.0
# 1576  FFF61080    12               1329                        1329.0
#
#       fractional_norm_count
# 0                  0.101033
# 1                  0.069141
# 2                  0.079043
# 3                  0.082537
# 4                  0.099970
# ...                     ...
# 1572               0.043272
# 1573               0.105363
# 1574               0.044222
# 1575               0.026533
# 1576               0.030062
#
# [1577 rows x 5 columns]

# %%
df_ebird_135_final = df_ebird_135.pivot_table(index=['AVIBASEID'], columns=['MONTH'], values='fractional_norm_count', aggfunc='sum')

# %%
df_ebird_135_final
# Out:
# MONTH            01        02        03        04        05        06  \
# AVIBASEID
# 00124D98   0.101033  0.069141  0.079043  0.082537  0.099970  0.064853
# 01060BFD   0.042601  0.028030  0.015009  0.104647  0.007647  0.000603
# 018B3169   0.241749  0.198311  0.124959  0.064853  0.003864  0.001435
# 03AC32BA   0.171170  0.234250  0.088187  0.020715  0.004330  0.002129
# 0413ED30   0.062670  0.058796  0.058444  0.038232  0.001311       NaN
# ...             ...       ...       ...       ...       ...       ...
# FC366114   0.135613  0.085831  0.110194  0.097121  0.064439  0.045226
# FD2B0309   0.161156  0.019141  0.037676  0.057881  0.111489  0.078944
# FED3756C   0.188019  0.126372  0.122423  0.099197  0.084471  0.059036
# FF592882   0.068940  0.054811  0.072348  0.068650  0.078758  0.086375
# FFF61080   0.021376  0.014092  0.106811  0.309892  0.163496  0.098147
#
# MONTH            07        08        09        10        11        12
# AVIBASEID
# 00124D98   0.062318  0.081870  0.094423  0.066693  0.074610  0.123511
# 01060BFD   0.132881  0.308675  0.188354  0.057826  0.067805  0.045921
# 018B3169   0.000662  0.001711  0.003256  0.032178  0.145601  0.181422
# 03AC32BA   0.003446  0.001841  0.004145  0.034189  0.139419  0.296179
# 0413ED30   0.012004  0.101460  0.187462  0.168708  0.173120  0.137794
# ...             ...       ...       ...       ...       ...       ...
# FC366114   0.039218  0.051103  0.103658  0.078503  0.071834  0.117259
# FD2B0309   0.166592  0.107188  0.092156  0.046604  0.041711  0.079462
# FED3756C   0.031660  0.020348  0.017135  0.035542  0.090361  0.125435
# FF592882   0.073960  0.086853  0.146187  0.102367  0.075654  0.085096
# FFF61080   0.036735  0.043272  0.105363  0.044222  0.026533  0.030062
#
# [135 rows x 12 columns]

# %%
df_ebird_135_final.fillna(0, inplace=True)

# %%
df_ebird_135_final
# Out:
# MONTH            01        02        03        04        05        06  \
# AVIBASEID
# 00124D98   0.101033  0.069141  0.079043  0.082537  0.099970  0.064853
# 01060BFD   0.042601  0.028030  0.015009  0.104647  0.007647  0.000603
# 018B3169   0.241749  0.198311  0.124959  0.064853  0.003864  0.001435
# 03AC32BA   0.171170  0.234250  0.088187  0.020715  0.004330  0.002129
# 0413ED30   0.062670  0.058796  0.058444  0.038232  0.001311  0.000000
# ...             ...       ...       ...       ...       ...       ...
# FC366114   0.135613  0.085831  0.110194  0.097121  0.064439  0.045226
# FD2B0309   0.161156  0.019141  0.037676  0.057881  0.111489  0.078944
# FED3756C   0.188019  0.126372  0.122423  0.099197  0.084471  0.059036
# FF592882   0.068940  0.054811  0.072348  0.068650  0.078758  0.086375
# FFF61080   0.021376  0.014092  0.106811  0.309892  0.163496  0.098147
#
# MONTH            07        08        09        10        11        12
# AVIBASEID
# 00124D98   0.062318  0.081870  0.094423  0.066693  0.074610  0.123511
# 01060BFD   0.132881  0.308675  0.188354  0.057826  0.067805  0.045921
# 018B3169   0.000662  0.001711  0.003256  0.032178  0.145601  0.181422
# 03AC32BA   0.003446  0.001841  0.004145  0.034189  0.139419  0.296179
# 0413ED30   0.012004  0.101460  0.187462  0.168708  0.173120  0.137794
# ...             ...       ...       ...       ...       ...       ...
# FC366114   0.039218  0.051103  0.103658  0.078503  0.071834  0.117259
# FD2B0309   0.166592  0.107188  0.092156  0.046604  0.041711  0.079462
# FED3756C   0.031660  0.020348  0.017135  0.035542  0.090361  0.125435
# FF592882   0.073960  0.086853  0.146187  0.102367  0.075654  0.085096
# FFF61080   0.036735  0.043272  0.105363  0.044222  0.026533  0.030062
#
# [135 rows x 12 columns]

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=12)

# %%
pca.fit(df_ebird_135_final.values)
# Out:
# PCA(n_components=12)

# %%
pca.explained_variance_ratio_
# Out:
# array([4.89832273e-01, 1.94295270e-01, 9.88913260e-02, 5.47359912e-02,
#        4.75314754e-02, 3.48193711e-02, 2.30538880e-02, 2.10316050e-02,
#        1.50305189e-02, 1.16061240e-02, 9.17215772e-03, 1.22176438e-32])

# %%
np.cumsum(pca.explained_variance_ratio_)
# Out:
# array([0.48983227, 0.68412754, 0.78301887, 0.83775486, 0.88528634,
#        0.92010571, 0.94315959, 0.9641912 , 0.97922172, 0.99082784,
#        1.        , 1.        ])

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.title("Scree Plot")
plt.show()

# %%
df_ebird_135_final.iloc[0:2, :].T.plot()
# Out:
# <Axes: xlabel='MONTH'>

# %%
plt.plot(pca.components_[0])

# %%
plt.plot(pca.components_[1])

# %%
df_ebird_135_final.loc['F6C6C3F7', :].plot()
plt.title('Plot for Setophaga townsendi')
plt.show()

# %%
avibase_ids_3birds = ['9C5ED06A', 'F6C6C3F7', '7E327303']
fig, ax = plt.subplots(1,1,figsize=(10,8))
df_ebird_135_final.loc[avibase_ids_3birds, :].T.plot(ax=ax)
plt.legend(['Meleagris gallopavo',
'Setophaga townsendi',
'Melanerpes formicivorus'])
plt.title("Relative Frequency of Sightings for some select Birds")
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xlabel("Month of the Year")
ax.set_ylabel("Relative Frequency of Sightings")
plt.show()

# %%
from scipy.stats import wasserstein_distance

# %%
pca_0_ebird = pca.components_[0]
pca_0_iNat = [-0.35573337, -0.20986457, -0.14651709,  0.32215211,  0.3638388 ,
         0.37216271,  0.27346115,  0.21639022,  0.07833495, -0.17139628,
        -0.35997586, -0.38285277]

# %%
wasserstein_distance(pca_0_ebird, pca_0_iNat)
# Out:
# 0.03197332551191766

# %%
pca_1_ebird = pca.components_[1]
pca_1_iNat = [-0.17257609, -0.13355367, -0.28602856, -0.42885556, -0.21925946,
        -0.14144298,  0.10355929,  0.51894009,  0.52696792,  0.20732324,
         0.10616067, -0.08123489]

# %%
wasserstein_distance(pca_1_ebird, pca_1_iNat)
# Out:
# 0.05147373508503635

# %% [markdown]
# # Exporting those 135 birds and their counts

# %%
df_ebird_135.to_csv('ebird_data_135_not_normalized.csv')
